# %%
import requests
import json

def get_author_details(author_ids):
    BASE_URL = "https://api.semanticscholar.org/graph/v1/author/{}"
    FIELDS = "?fields=name,paperCount,citationCount,hIndex,affiliations"
    PAPER_FIELDS = "/papers?fields=paperId,corpusId,title&limit=1000"

    authors = []

    for author_id in author_ids:
        url = BASE_URL.format(author_id) + FIELDS
        response = requests.get(url)
        
        if response.status_code == 200:
            data = response.json()

            author_data = {
                "author_id": data.get("authorId", ""),
                "author_name": data.get("name", ""),
                "paper_count": data.get("paperCount", ""),
                "citation_count": data.get("citationCount", ""),
                "hindex": data.get("hIndex", ""),
                "affiliations": [affiliation for affiliation in data.get("affiliations", [])],
                "papers": [],
            }
            author_data['author_name'] = author_data['author_name'].replace("Jimmy J.", "Jimmy")
            # Fetching author's papers
            papers_url = BASE_URL.format(author_id) + PAPER_FIELDS
            papers_response = requests.get(papers_url)
            if papers_response.status_code == 200:
                papers_data = papers_response.json()
                for paper in papers_data.get("data", []):
                    paper_info = {
                        "paper_id": paper.get("paperId", ""),
                        "corpus_id": paper.get("corpusId", ""),
                        "title": paper.get("title", "")
                    }
                    author_data["papers"].append(paper_info)

            authors.append(author_data)
        else:
            print(f"Failed to retrieve data for author ID: {author_id}")

    return authors

# Example usage
author_ids = ["145580839", "1816753042", "1982950", "144783904", "2166511", "2928777", "2154743364", '2154743381', '2121626141']  # Add more author IDs to this list as needed

MAP_WRONG_ID_TO_CORRECT_ID = {"2154743364":"145580839", "2154743381":"145580839", "2121626141":"145580839"}
author_details = get_author_details(author_ids)
# Sort author details by paper_count
new_authors = []
for author in author_details:
    if author["author_id"] in MAP_WRONG_ID_TO_CORRECT_ID:
        author["author_id"] = MAP_WRONG_ID_TO_CORRECT_ID.get(author["author_id"], author["author_id"])
        for new_author in new_authors:
            if new_author["author_id"] == author["author_id"]:
                new_author["paper_count"] += author["paper_count"]
                new_author["citation_count"] += author["citation_count"]
                new_author["papers"] += author["papers"]
    else:
        new_authors.append(author)
    # Find author in author_details with this author_id and add all papers to that author
author_details = new_authors[:]
author_details = sorted(author_details, key=lambda x: x["paper_count"], reverse=False)
print(json.dumps(author_details, indent=4))
# print obfuscating the paper details
for author in author_details:
    print(author["author_name"])
    print(author["paper_count"])
    print(author["citation_count"])
    print(author["hindex"])
    print(len(author["papers"]))
# Out:
# [
#     {
#         "author_id": "1816753042",
#         "author_name": "Ronak Pradeep",
#         "paper_count": 27,
#         "citation_count": 856,
#         "hindex": 10,
#         "affiliations": [
#             "University of Waterloo"
#         ],
#         "papers": [
#             {
#                 "paper_id": "20a7b1e274aff828466bba3760992aa54e14951a",
#                 "corpus_id": 258822999,
#                 "title": "How Does Generative Retrieval Scale to Millions of Passages?"
#             },
#             {
#                 "paper_id": "532a24fbf508c40234e9126c7a3f80dd92e8545f",
#                 "corpus_id": 257584922,
#                 "title": "Pre-processing Matters! Improved Wikipedia Corpora for Open-Domain Question Answering"
#             },
#             {
#                 "paper_id": "6a0c18aa1bf69798b15ef2355d5256ae8fa80186",
#                 "corpus_id": 257584993,
#                 "title": "PyGaggle: A Gaggle of Resources for Open-Domain Question Answering"
#             },
#             {
#                 "paper_id": "8be0ec99f80710887e3a8e6bac5fba51a8fd7186",
#                 "corpus_id": 258461030,
#                 "title": "Zero-Shot Listwise Document Reranking with a Large Language Model"
#             },
#             {
#                 "paper_id": "8dec602dcd4df3db500ad36d01fffd53ec92701a",
#                 "corpus_id": 259145284,
#                 "title": "ReadProbe: A Demo of Retrieval-Enhanced Large Language Models to Support Lateral Reading"
#             },
#             {
#                 "paper_id": "a08bde10a47059b0ba1e58b425dd080ec9b42339",
#                 "corpus_id": 261276669,
#                 "title": "Vector Search with OpenAI Embeddings: Lucene Is All You Need"
#             },
#             {
#                 "paper_id": "ba03ca8faa9f01cd9d26b80f08d421376f70de22",
#                 "corpus_id": 262825475,
#                 "title": "RankVicuna: Zero-Shot Listwise Document Reranking with Open-Source Large Language Models"
#             },
#             {
#                 "paper_id": "35a318073ab5b18cf364699e145a750940bcedb3",
#                 "corpus_id": 249319651,
#                 "title": "Neural Query Synthesis and Domain-Specific Ranking Templates for Multi-Stage Clinical Trial Matching"
#             },
#             {
#                 "paper_id": "423f94251781e9169f2a96bb3208f7feb2a89b0e",
#                 "corpus_id": 250340319,
#                 "title": "Document Expansion Baselines and Learned Sparse Lexical Representations for MS MARCO V1 and V2"
#             },
#             {
#                 "paper_id": "586b9d75afdbb09434c8676fb10a5b0072882bfc",
#                 "corpus_id": 252900208,
#                 "title": "Voice Recognition Chat bot for Consumer Product Applications"
#             },
#             {
#                 "paper_id": "74043ae76b95ad34ee9f31d89549aa1c1c820fed",
#                 "corpus_id": 248003306,
#                 "title": "Another Look at DPR: Reproduction of Training and Replication of Retrieval"
#             },
#             {
#                 "paper_id": "d0629d89120409b6bb2c7cc3b309b15839ff73cb",
#                 "corpus_id": 248003253,
#                 "title": "Squeezing Water from a Stone: A Bag of Tricks for Further Improving Cross-Encoder Effectiveness for Reranking"
#             },
#             {
#                 "paper_id": "eac257efef9ed0230b0036f9c5f478de94333fb6",
#                 "corpus_id": 249319719,
#                 "title": "Document Expansions and Learned Sparse Lexical Representations for MS MARCO V1 and V2"
#             },
#             {
#                 "paper_id": "007a06e9674f58d496ef36ef54a2fd1363299c08",
#                 "corpus_id": 235351886,
#                 "title": "Chatty Goose: A Python Framework for Conversational Search"
#             },
#             {
#                 "paper_id": "0c1d53fc87ca482037360b3547111158b505b26e",
#                 "corpus_id": 235719102,
#                 "title": "Exploring Listwise Evidence Reasoning with T5 for Fact Verification"
#             },
#             {
#                 "paper_id": "4e12f790879dcbaa10b43d562f70e926c15b9f50",
#                 "corpus_id": 240560203,
#                 "title": "Analysing Research Trends Using Topic Modelling and Trend Prediction"
#             },
#             {
#                 "paper_id": "550bdac3647db92f64e5093862209ffc443783f6",
#                 "corpus_id": 233268465,
#                 "title": "Comparison of Foveated Downsampling Techniques in Image Recognition"
#             },
#             {
#                 "paper_id": "5ac627f229fa8d54f5ad43f7f99e9b29d93ada29",
#                 "corpus_id": 231979055,
#                 "title": "Pyserini: An Easy-to-Use Python Toolkit to Support Replicable IR Research with Sparse and Dense Representations"
#             },
#             {
#                 "paper_id": "7a4c0523dbb99e2b437ab8e222420e193a517686",
#                 "corpus_id": 235477259,
#                 "title": "Vera: Prediction Techniques for Reducing Harmful Misinformation in Consumer Health Search"
#             },
#             {
#                 "paper_id": "89a19523b0cfb587d272b9ceb950c7bc4e8e221e",
#                 "corpus_id": 233219855,
#                 "title": "A Replication Study of Dense Passage Retriever"
#             },
#             {
#                 "paper_id": "d69c0ed04ecc852e8c921900d3e7967f74f81263",
#                 "corpus_id": 235366815,
#                 "title": "Pyserini: A Python Toolkit for Reproducible Information Retrieval Research with Sparse and Dense Representations"
#             },
#             {
#                 "paper_id": "e08eed9608382beea1febca49119c665fbabd031",
#                 "corpus_id": 231603106,
#                 "title": "The Expando-Mono-Duo Design Pattern for Text Ranking with Pretrained Sequence-to-Sequence Models"
#             },
#             {
#                 "paper_id": "4b91247cc0692f34eb3e39485aa3d2d4e8ac9dc5",
#                 "corpus_id": 232134157,
#                 "title": "H2oloo at TREC 2020: When all you got is a hammer... Deep Learning, Health Misinformation, and Precision Medicine"
#             },
#             {
#                 "paper_id": "e3e36944102c9baee49dfec397fc0e4bb63a7c77",
#                 "corpus_id": 220525829,
#                 "title": "Covidex: Neural Ranking Models and Keyword Search Infrastructure for the COVID-19 Open Research Dataset"
#             },
#             {
#                 "paper_id": "e4cb6bfe88a8ed729d34d5a9ff74a992932b70ce",
#                 "corpus_id": 225040083,
#                 "title": "Scientific Claim Verification with VerT5erini"
#             },
#             {
#                 "paper_id": "f6e0164466e827112fd415afdc28ddf8e0eb1ba3",
#                 "corpus_id": 212725651,
#                 "title": "Document Ranking with a Pretrained Sequence-to-Sequence Model"
#             },
#             {
#                 "paper_id": "059fa9a5578cf1ca241b87455eb75803bc6483c0",
#                 "corpus_id": 146167879,
#                 "title": "Determining a Slogan: The Use of Nominal Group Technique and Q Methology to Develop and Select an Advertising Slogan"
#             }
#         ]
#     },
#     {
#         "author_id": "2928777",
#         "author_name": "Wenhu Chen",
#         "paper_count": 58,
#         "citation_count": 2907,
#         "hindex": 23,
#         "affiliations": [
#             "University of Waterloo"
#         ],
#         "papers": [
#             {
#                 "paper_id": "0139e689add40a61c9454674edac4e93702aa5fc",
#                 "corpus_id": 258461017,
#                 "title": "Few-shot In-context Learning on Knowledge Base Question Answering"
#             },
#             {
#                 "paper_id": "19363e9fa47f02744d49f24b8e94c8cdf19bc4af",
#                 "corpus_id": 259287024,
#                 "title": "LyricWhiz: Robust Multilingual Zero-shot Lyrics Transcription by Whispering to ChatGPT"
#             },
#             {
#                 "paper_id": "2cf1de499a91aaef4695c716f37bbad9868ecec5",
#                 "corpus_id": 259224605,
#                 "title": "DreamEdit: Subject-driven Image Editing"
#             },
#             {
#                 "paper_id": "5e761e9f5cd9672a181b256299cd2916a8079461",
#                 "corpus_id": 261557644,
#                 "title": "Augmenting Black-box LLMs with Medical Textbooks for Clinical Question Answering"
#             },
#             {
#                 "paper_id": "83b8e18488d8f31dd017ec0b26531cef4b635b36",
#                 "corpus_id": 257913352,
#                 "title": "Subject-driven Text-to-Image Generation via Apprenticeship Learning"
#             },
#             {
#                 "paper_id": "8c2c60a078a5cc9a38a4311c7b400eca0fc0b2dc",
#                 "corpus_id": 259202664,
#                 "title": "MARBLE: Music Audio Representation Benchmark for Universal Evaluation"
#             },
#             {
#                 "paper_id": "a3dd7d33dfaa9e02e43d92e900cba01f52d8c4b9",
#                 "corpus_id": 261696697,
#                 "title": "MAmmoTH: Building Math Generalist Models through Hybrid Instruction Tuning"
#             },
#             {
#                 "paper_id": "a52dd1e900200e0733eea927edc7d6c27aeba187",
#                 "corpus_id": 258833200,
#                 "title": "TheoremQA: A Theorem-driven Question Answering dataset"
#             },
#             {
#                 "paper_id": "bc1e80f23e98e0b500b94ef82e7b54359b6e8615",
#                 "corpus_id": 258841061,
#                 "title": "EDIS: Entity-Driven Image Search over Multimodal Web Content"
#             },
#             {
#                 "paper_id": "d00e8c454fc369d54a6d25a9cd2723ca848af7f0",
#                 "corpus_id": 262043691,
#                 "title": "MusiLingo: Bridging Music and Text with Pre-trained Language Models for Music Captioning and Query Response"
#             },
#             {
#                 "paper_id": "ecf38d702bea560c1f9d372645e2be7661a71f37",
#                 "corpus_id": 259187796,
#                 "title": "MagicBrush: A Manually Annotated Dataset for Instruction-Guided Image Editing"
#             },
#             {
#                 "paper_id": "fb08b08916caab4b22c60fa96753f6b9a5886d75",
#                 "corpus_id": 258999603,
#                 "title": "MERT: Acoustic Music Understanding Model with Large-Scale Self-supervised Training"
#             },
#             {
#                 "paper_id": "33ef78737ba57ecc1ff98c22369a8e17ed90eb98",
#                 "corpus_id": 253734226,
#                 "title": "Synthesizing Coherent Story with Auto-Regressive Latent Diffusion Models"
#             },
#             {
#                 "paper_id": "38b0803b59e4973f09018ce942164b02be4b8bc9",
#                 "corpus_id": 252735160,
#                 "title": "MuRAG: Multimodal Retrieval-Augmented Generator for Open Question Answering over Images and Text"
#             },
#             {
#                 "paper_id": "4d3a49d1439a0b8fbb0e9f588970ad0f1d70dec8",
#                 "corpus_id": 254877346,
#                 "title": "DePlot: One-shot visual language reasoning by plot-to-table translation"
#             },
#             {
#                 "paper_id": "598d9b235f5ab148fc757240d9bc39a47b8eaf72",
#                 "corpus_id": 253801709,
#                 "title": "Program of Thoughts Prompting: Disentangling Computation from Reasoning for Numerical Reasoning Tasks"
#             },
#             {
#                 "paper_id": "7d29a84a589aa5655e5d3fed8d725ea472816599",
#                 "corpus_id": 252873123,
#                 "title": "Explanations from Large Language Models Make Small Reasoners Better"
#             },
#             {
#                 "paper_id": "8add69e155596bc128df70e1ddd5a41c68698399",
#                 "corpus_id": 252780701,
#                 "title": "Controllable Dialogue Simulation with In-Context Learning"
#             },
#             {
#                 "paper_id": "9fc3a0e96f2fa6bc7a92a96d61c68f7cb09f0a8f",
#                 "corpus_id": 248085193,
#                 "title": "Augmenting Pre-trained Language Models with QA-Memory for Open-Domain Question Answering"
#             },
#             {
#                 "paper_id": "b5c80cd17a3be2c2f9cb02974e140ac361f417ff",
#                 "corpus_id": 250264121,
#                 "title": "QA Is the New KR: Question-Answer Pairs as Knowledge Bases"
#             },
#             {
#                 "paper_id": "e66f0f822d4c4853b39b27daaafa2993005fd55e",
#                 "corpus_id": 252872943,
#                 "title": "Large Language Models are few(1)-shot Table Reasoners"
#             },
#             {
#                 "paper_id": "ec1ac8df419a241c3cc6bfd209a38b494af792ee",
#                 "corpus_id": 252596087,
#                 "title": "Re-Imagen: Retrieval-Augmented Text-to-Image Generator"
#             },
#             {
#                 "paper_id": "3ad97f70b309a9be3eb37a397db6e3d0b11b86c9",
#                 "corpus_id": 249551392,
#                 "title": "Accessing Diverse Web Knowledge with Natural Language Interface"
#             },
#             {
#                 "paper_id": "27db72a2f643f9dfebc0cc2e8b98a9db307f0f07",
#                 "corpus_id": 215785913,
#                 "title": "HybridQA: A Dataset of Multi-Hop Question Answering over Tabular and Textual Data"
#             },
#             {
#                 "paper_id": "342ec2f1c1b3d29d3269a2566c44f239f0141aeb",
#                 "corpus_id": 216056509,
#                 "title": "Logical Natural Language Generation from Open-Domain Tables"
#             },
#             {
#                 "paper_id": "405c0d9b7cf5482d2e1197167f690e7b7801b9bd",
#                 "corpus_id": 225066758,
#                 "title": "Unsupervised Multi-hop Question Answering by Question Generation"
#             },
#             {
#                 "paper_id": "68bebcf1ae2c0aff880971abd085dcde757922ff",
#                 "corpus_id": 223957241,
#                 "title": "Modeling Token-level Uncertainty to Learn Unknown Concepts in SLU via Calibrated Dirichlet Prior RNN"
#             },
#             {
#                 "paper_id": "6f335995b65eefa3ddf54b291abf211bc7ed4ed9",
#                 "corpus_id": 226283587,
#                 "title": "KGLM: Pretrained Knowledge-Grounded Language Model for Data-to-Text Generation"
#             },
#             {
#                 "paper_id": "6f33bd4e62955f4d40424f8ae4ec83af4e97862c",
#                 "corpus_id": 222141577,
#                 "title": "KGPT: Knowledge-Grounded Pre-Training for Data-to-Text Generation"
#             },
#             {
#                 "paper_id": "704ec27b8399df574a96da338c428a923509385e",
#                 "corpus_id": 214668012,
#                 "title": "Violin: A Large-Scale Dataset for Video-and-Language Inference"
#             },
#             {
#                 "paper_id": "93d3e45395117e21214d404c8753b578c29266d1",
#                 "corpus_id": 224803601,
#                 "title": "Open Question Answering over Tables and Text"
#             },
#             {
#                 "paper_id": "af5f6eb99d930dd8737ac81566d07e646911ba57",
#                 "corpus_id": 225846930,
#                 "title": "Developments of NDE method of jacket welds for ITER In-Vessel coil joints"
#             },
#             {
#                 "paper_id": "c807a8c169925412d74a995ecf8ba898fd78f7d1",
#                 "corpus_id": 216914911,
#                 "title": "Logic2Text: High-Fidelity Natural Language Generation from Logical Forms"
#             },
#             {
#                 "paper_id": "f6297a372bc4e6b4843a251b73fc46f720386e33",
#                 "corpus_id": 210064470,
#                 "title": "Generative Adversarial Zero-Shot Relational Learning for Knowledge Graphs"
#             },
#             {
#                 "paper_id": "0ddd7c9a1955c76eb831a230ef20a68b662886bb",
#                 "corpus_id": 196179208,
#                 "title": "Mining Algorithm Roadmap in Scientific Publications"
#             },
#             {
#                 "paper_id": "320464aa0231bc728c7d9ab7e71e552c12a7486b",
#                 "corpus_id": 203902269,
#                 "title": "Meta Module Network for Compositional Visual Reasoning"
#             },
#             {
#                 "paper_id": "3691d01a849c7256a9214b346b2fdeeb1c8a963e",
#                 "corpus_id": 53981714,
#                 "title": "Global Textual Relation Embedding for Relational Understanding"
#             },
#             {
#                 "paper_id": "36e30516683032634975c53e60f3737b6e35ff80",
#                 "corpus_id": 195766887,
#                 "title": "Enhancing the Locality and Breaking the Memory Bottleneck of Transformer on Time Series Forecasting"
#             },
#             {
#                 "paper_id": "4d7df81767737c81890411c7f1685bb232921cb7",
#                 "corpus_id": 170078653,
#                 "title": "Semantically Conditioned Dialog Response Generation via Hierarchical Disentangled Self-Attention"
#             },
#             {
#                 "paper_id": "608adcc7e2922cfe7e2577b679526cd4e4f06c76",
#                 "corpus_id": 67856413,
#                 "title": "How Large a Vocabulary Does Text Classification Need? A Variational Approach to Vocabulary Selection"
#             },
#             {
#                 "paper_id": "dd9243398e05c4d4403a5e4dba6d2c6e0102a07d",
#                 "corpus_id": 203588801,
#                 "title": "Towards Democratizing Data Science with Natural Language Interfaces"
#             },
#             {
#                 "paper_id": "ee4e24bdedd4d2e4be977bd0ca9f68a06ebb4d96",
#                 "corpus_id": 198917339,
#                 "title": "TabFact: A Large-scale Dataset for Table-based Fact Verification"
#             },
#             {
#                 "paper_id": "feb79e1ed36ca9f9efa2792bbbeeabf87227c85f",
#                 "corpus_id": 202753975,
#                 "title": "Interpreting and Improving Deep Neural SLU Models via Vocabulary Importance"
#             },
#             {
#                 "paper_id": "0af4274ddc948bb175be7662a699a8270878ced2",
#                 "corpus_id": 13751352,
#                 "title": "No Metrics Are Perfect: Adversarial Reward Learning for Visual Storytelling"
#             },
#             {
#                 "paper_id": "4ae0907151cdc0fc0d9aaf0982e783c9652dc7a2",
#                 "corpus_id": 4669223,
#                 "title": "Variational Knowledge Graph Reasoning"
#             },
#             {
#                 "paper_id": "747f6c8205061c619d0af6342918c7ae8e17108d",
#                 "corpus_id": 52090309,
#                 "title": "Approximate Distribution Matching for Sequence-to-Sequence Learning"
#             },
#             {
#                 "paper_id": "c9ba6618e9691240ce68061a778d0cbb283d3fa4",
#                 "corpus_id": 67856169,
#                 "title": "A Variational Dirichlet Framework for Out-of-Distribution Detection"
#             },
#             {
#                 "paper_id": "cd086480d4bcb1fc7f10a0343fa202bbb84c6527",
#                 "corpus_id": 53714375,
#                 "title": "Enhancing the Robustness of Prior Network in Out-of-Distribution Detection"
#             },
#             {
#                 "paper_id": "e8b02e05d44c7b1ec9dac3e211eef62a3cd2d9f3",
#                 "corpus_id": 44128838,
#                 "title": "Triangular Architecture for Rare Language Translation"
#             },
#             {
#                 "paper_id": "ff065acdde4b8b6cb1e0386924d72cdcee058503",
#                 "corpus_id": 52050424,
#                 "title": "XL-NBT: A Cross-lingual Neural Belief Tracking Framework"
#             },
#             {
#                 "paper_id": "74b284a66e75b65f5970d05bac000fe91243ee49",
#                 "corpus_id": 4433804,
#                 "title": "Video Captioning via Hierarchical Reinforcement Learning"
#             },
#             {
#                 "paper_id": "7f73d3bca218b1a27be1142a08815cad7cce0d3d",
#                 "corpus_id": 195347778,
#                 "title": "Neural Sequence Prediction by Coaching"
#             },
#             {
#                 "paper_id": "bdd537840efe4a048b5eead24c683d33091585af",
#                 "corpus_id": 3987603,
#                 "title": "Generative Bridging Network in Neural Sequence Prediction"
#             },
#             {
#                 "paper_id": "4fa6a688f350831503d158f8f618c58d1e06bc5d",
#                 "corpus_id": 40005428,
#                 "title": "A Semi-supervised Framework for Image Captioning"
#             },
#             {
#                 "paper_id": "8cc23e554d98522b377d227dc78e9382a0ed35e5",
#                 "corpus_id": 6137408,
#                 "title": "Bootstrap, Review, Decode: Using Out-of-Domain Textual Data to Improve Image Captioning"
#             },
#             {
#                 "paper_id": "afd528af8df5e371a1282f0a05bdf68b4cb80fc2",
#                 "corpus_id": 17078659,
#                 "title": "Guided Alignment Training for Topic-Aware Neural Machine Translation"
#             },
#             {
#                 "paper_id": "d0b7d3f9a59034d44e7cd1b434cfd27136a7c029",
#                 "corpus_id": 10622921,
#                 "title": "Facial Emotion Recognition Using PHOG and a Hierarchical Expression Model"
#             },
#             {
#                 "paper_id": "d15ce9f4629226853e305f627e73efe3e75b76b4",
#                 "corpus_id": 54935107,
#                 "title": "IMPROVING TRADITIONAL BUILDING REPAIR CONSTRUCTION QUALITY USING HISTORIC BUILDING INFORMATION MODELING CONCEPT"
#             }
#         ]
#     },
#     {
#         "author_id": "2166511",
#         "author_name": "R. Socher",
#         "paper_count": 201,
#         "citation_count": 124005,
#         "hindex": 80,
#         "affiliations": [],
#         "papers": [
#             {
#                 "paper_id": "1c00ac5f977e34fb96311321793880be3e490b8f",
#                 "corpus_id": 257055520,
#                 "title": "Author Correction: Prostate cancer therapy personalization via multi-modal deep learning on randomized phase III clinical trials"
#             },
#             {
#                 "paper_id": "835c305e52769a8433f8383e91d33ba6c66ad55b",
#                 "corpus_id": 256304602,
#                 "title": "Large language models generate functional protein sequences across diverse families"
#             },
#             {
#                 "paper_id": "03e1b8fb7e9b8a395ffda00fa5212926ed98385a",
#                 "corpus_id": 248525885,
#                 "title": "The AI Economist: Taxation policy design via two-level deep multiagent reinforcement learning"
#             },
#             {
#                 "paper_id": "64d4154a5a2fe1a9e1e369bac56fd3eb01cd5b0d",
#                 "corpus_id": 247618731,
#                 "title": "Converse: A Tree-Based Modular Task-Oriented Dialogue System"
#             },
#             {
#                 "paper_id": "97eb9f70d04f062f2f809623b3caacade31d50d9",
#                 "corpus_id": 249438078,
#                 "title": "Prostate cancer therapy personalization via multi-modal deep learning on randomized phase III clinical trials"
#             },
#             {
#                 "paper_id": "d36dcc52d9d8bc1a4b43469977653cebce579dd8",
#                 "corpus_id": 247976230,
#                 "title": "Extracting structural folding pattern of chromatin using chromatin condensation data using HiCNN[12] or HiCNN2[13] approaches Metrics for evaluation: Comparing the result\u2019s mean squared error and Pearson\u2019s correlation coefficients with experimental high-resolution Hi-C data"
#             },
#             {
#                 "paper_id": "0ac42824e4e11a7e3f365562f5188be6db6dc22d",
#                 "corpus_id": 238417917,
#                 "title": "Biological data annotation via a human-augmenting AI-based labeling system"
#             },
#             {
#                 "paper_id": "0bfb1e3b79d5da726d4fe45a3863c32e95c7ad4d",
#                 "corpus_id": 236924496,
#                 "title": "The AI Economist: Optimal Economic Policy Design via Two-level Deep Reinforcement Learning"
#             },
#             {
#                 "paper_id": "0f9377559b1db5051356c9c6f0c01f317b9bd5bb",
#                 "corpus_id": 234029542,
#                 "title": "Biological data annotation via a human-augmenting AI-based labeling interface"
#             },
#             {
#                 "paper_id": "15a89e6c99e46802ac44a9eead092350f3920776",
#                 "corpus_id": 236145763,
#                 "title": "Deep neural language modeling enables functional protein generation across families"
#             },
#             {
#                 "paper_id": "59cc829af19b7711c05dd9f2d12a0e7fe4a65569",
#                 "corpus_id": 233206583,
#                 "title": "COVID-19 information retrieval with deep-learning based semantic search, question answering, and abstractive summarization"
#             },
#             {
#                 "paper_id": "6c54c4a62bbd0cecd260c43923d15f913bce5fea",
#                 "corpus_id": 235358945,
#                 "title": "Evaluating State-of-the-Art Classification Models Against Bayes Optimality"
#             },
#             {
#                 "paper_id": "c3df199cbca74763c4ae9889409bbd4aa29b6255",
#                 "corpus_id": 231202901,
#                 "title": "Deep learning-enabled medical computer vision"
#             },
#             {
#                 "paper_id": "01ec011977fc6cda03e8b447e1b5eb0551f1c961",
#                 "corpus_id": 218487751,
#                 "title": "A Simple Language Model for Task-Oriented Dialogue"
#             },
#             {
#                 "paper_id": "027ebcf65f5d221c040a6586e5ed743b6d121aa6",
#                 "corpus_id": 211068721,
#                 "title": "Explore, Discover and Learn: Unsupervised Discovery of State-Covering Skills"
#             },
#             {
#                 "paper_id": "034f92d013bf3b96510c63b15bb007e399bbc9ae",
#                 "corpus_id": 213576607,
#                 "title": "Dye-sensitized solar cells under ambient light powering machine learning: towards autonomous smart sensors for the internet of things\u2020"
#             },
#             {
#                 "paper_id": "0544af8d6b6b6e9ce14be9c6425e520a638be380",
#                 "corpus_id": 220058500,
#                 "title": "Photon: A Robust Cross-Domain Text-to-SQL System"
#             },
#             {
#                 "paper_id": "05678c16217263362209e785122286eebd22749d",
#                 "corpus_id": 226236899,
#                 "title": "Contextual Salience for Fast and Accurate Sentence Vectors."
#             },
#             {
#                 "paper_id": "07bcda1dff9bb696ea9cbc69303eee8bd3d85bd6",
#                 "corpus_id": 221655075,
#                 "title": "GeDi: Generative Discriminator Guided Sequence Generation"
#             },
#             {
#                 "paper_id": "0f83caa4f4a75f7570315c3b59b68ef4ef723677",
#                 "corpus_id": 211818164,
#                 "title": "Towards Noise-resistant Object Detection with Noisy Annotations"
#             },
#             {
#                 "paper_id": "1313b3bd5fd5801cb9c3ac0561ccc3fed3189438",
#                 "corpus_id": 211069035,
#                 "title": "Taylorized Training: Towards Better Approximation of Neural Network Training at Finite Width"
#             },
#             {
#                 "paper_id": "1ae00bef8a43b37d435c7ce9d817ff76c0d48f13",
#                 "corpus_id": 215548298,
#                 "title": "An Investigation of Phone-Based Subword Units for End-to-End Speech Recognition"
#             },
#             {
#                 "paper_id": "22125c5f56fb2504994f1bbe1a9464c23aa17f1a",
#                 "corpus_id": 210848920,
#                 "title": "Non-Autoregressive Dialog State Tracking"
#             },
#             {
#                 "paper_id": "232b40980acb55afa89ec50dd9806a5e551f699b",
#                 "corpus_id": 226283779,
#                 "title": "Bridging Textual and Tabular Data for Cross-Domain Text-to-SQL Semantic Parsing"
#             },
#             {
#                 "paper_id": "25a1070c7d2cca21731d1427038c49be370525a2",
#                 "corpus_id": 216562396,
#                 "title": "The AI Economist: Improving Equality and Productivity with AI-Driven Tax Policies"
#             },
#             {
#                 "paper_id": "27f0246890395d743252fd93282544c7efdec443",
#                 "corpus_id": 219721169,
#                 "title": "CO-Search: COVID-19 Information Retrieval with Semantic Search, Question Answering, and Abstractive Summarization"
#             },
#             {
#                 "paper_id": "2b364917b0c51e91fcf2ab9c1d66a14ed4b44c03",
#                 "corpus_id": 220249726,
#                 "title": "BERTology Meets Biology: Interpreting Attention in Protein Language Models"
#             },
#             {
#                 "paper_id": "39774032969627f8cfbb44c393c01538ea41d9ce",
#                 "corpus_id": 222341632,
#                 "title": "Explaining Creative Artifacts"
#             },
#             {
#                 "paper_id": "3ce2f7a1f857725ca3f477967aeef96ccf4eb0c4",
#                 "corpus_id": 229680169,
#                 "title": "Catastrophic Fisher Explosion: Early Phase Fisher Matrix Impacts Generalization"
#             },
#             {
#                 "paper_id": "3dfa2d2d7e13eb8b29be6f3bc97f518e94be09e5",
#                 "corpus_id": 218581359,
#                 "title": "It\u2019s Morphin\u2019 Time! Combating Linguistic Discrimination with Inflectional Perturbations"
#             },
#             {
#                 "paper_id": "446030903e114f9578bbf069925ff3e4f6606424",
#                 "corpus_id": 219531472,
#                 "title": "WOAD: Weakly Supervised Online Action Detection in Untrimmed Videos"
#             },
#             {
#                 "paper_id": "457eed4fd5c8109cf99821ff913648d5bed5fed8",
#                 "corpus_id": 216588685,
#                 "title": "COVID-19 Growth Rate Decreases with Social Capital"
#             },
#             {
#                 "paper_id": "4a92dfeace3fa3dac0e04eaceb486e518fdc9469",
#                 "corpus_id": 220101460,
#                 "title": "Assessing Local Generalization Capability in Deep Models"
#             },
#             {
#                 "paper_id": "4ecf4356c3b451b16780788a3f94e422d4deeda5",
#                 "corpus_id": 211171773,
#                 "title": "Tree-structured Attention with Hierarchical Accumulation"
#             },
#             {
#                 "paper_id": "5a0859bd66ec5b70f3230bdf2181fde1e641bfde",
#                 "corpus_id": 220265439,
#                 "title": "Theory-Inspired Path-Regularized Differential Network Architecture Search"
#             },
#             {
#                 "paper_id": "5ac342df3e0345827f64bdf6d055f138f6d0835e",
#                 "corpus_id": 220042269,
#                 "title": "Towards Understanding Hierarchical Learning: Benefits of Neural Representations"
#             },
#             {
#                 "paper_id": "5b015296730273921889e54a0a31e3b173017026",
#                 "corpus_id": 215768835,
#                 "title": "TOD-BERT: Pre-trained Natural Language Understanding for Task-Oriented Dialogue"
#             },
#             {
#                 "paper_id": "5f410910c3cf8b1affd189f0e1664997f13d39e1",
#                 "corpus_id": 218889485,
#                 "title": "Explicit Memory Tracker with Coarse-to-Fine Reasoning for Conversational Machine Reading"
#             },
#             {
#                 "paper_id": "632e312ab14ed3076699003d7014c222de9e0a69",
#                 "corpus_id": 213530362,
#                 "title": "Artificial intelligence for streamlined immunofluorescence-based biomarker discovery in prostate cancer."
#             },
#             {
#                 "paper_id": "6cba18bd36967eefa35a03b8f26c9664bbc11c02",
#                 "corpus_id": 201641861,
#                 "title": "A High-Quality Multilingual Dataset for Structured Documentation Translation"
#             },
#             {
#                 "paper_id": "6e3f8187f8fef3e11578a73f32da07d33dbf8235",
#                 "corpus_id": 220364230,
#                 "title": "DART: Open-Domain Structured Data Record to Text Generation"
#             },
#             {
#                 "paper_id": "741efeedb616045961efa9ae03a173bbc24a0560",
#                 "corpus_id": 214714010,
#                 "title": "Improving out-of-distribution generalization via multi-task self-supervised pretraining"
#             },
#             {
#                 "paper_id": "781b9a445d1878ee4744546f2b8c7466e3cbbd1a",
#                 "corpus_id": 220768873,
#                 "title": "SummEval: Re-evaluating Summarization Evaluation"
#             },
#             {
#                 "paper_id": "8602ac1d2b8528c741f444effdbd23f2e3be14a5",
#                 "corpus_id": 211252790,
#                 "title": "Neural Bayes: A Generic Parameterization Method for Unsupervised Representation Learning"
#             },
#             {
#                 "paper_id": "8b2cbb2f101b025c16e12d0d7628f65e5378e10d",
#                 "corpus_id": 221995589,
#                 "title": "GraPPa: Grammar-Augmented Pre-Training for Table Semantic Parsing"
#             },
#             {
#                 "paper_id": "8bf6c69bae0956db13aa9129fedc69fdc1256dce",
#                 "corpus_id": 218581596,
#                 "title": "Prototypical Contrastive Learning of Unsupervised Representations"
#             },
#             {
#                 "paper_id": "926329e8c699c7310a42c4090a5190870a05c8a5",
#                 "corpus_id": 225070214,
#                 "title": "Discriminative Nearest Neighbor Few-Shot Intent Detection by Transferring Natural Language Inference"
#             },
#             {
#                 "paper_id": "92b87d499f393f6258549e65e32c9331e49568ca",
#                 "corpus_id": 225041244,
#                 "title": "Online Structured Meta-learning"
#             },
#             {
#                 "paper_id": "92e0e66919569070196c951a71968414e5e01381",
#                 "corpus_id": 224705350,
#                 "title": "Explaining and Improving Model Behavior with k Nearest Neighbor Representations"
#             },
#             {
#                 "paper_id": "a6f3680df71e8151222a277a32601a4ab8fc177c",
#                 "corpus_id": 215797022,
#                 "title": "Optimal Feature Extraction based Machine Learning Approach for Sarcasm Type Detection in News Headlines"
#             },
#             {
#                 "paper_id": "be1ca892708727324fba9ca9c218702a652e8fcc",
#                 "corpus_id": 221819486,
#                 "title": "Composed Variational Natural Language Generation for Few-shot Intents"
#             },
#             {
#                 "paper_id": "c5f7074a264356c9a022a8dff24df79d1db8c3d3",
#                 "corpus_id": 214725226,
#                 "title": "ProGen: Language Modeling for Protein Generation"
#             },
#             {
#                 "paper_id": "ce435482acc0e195be8d8f002b2655b4c7b08be6",
#                 "corpus_id": 211146562,
#                 "title": "DivideMix: Learning with Noisy Labels as Semi-supervised Learning"
#             },
#             {
#                 "paper_id": "d1340b56e158eecce8432b9595fa9dd2c014c54b",
#                 "corpus_id": 218487410,
#                 "title": "ESPRIT: Explaining Solutions to Physical Reasoning Tasks"
#             },
#             {
#                 "paper_id": "d2b7e80346ad4ae730378a39d7b3ecf1b4564257",
#                 "corpus_id": 226988668,
#                 "title": "Deep learning-enabled breast cancer hormonal receptor status determination from base-level H&E stains"
#             },
#             {
#                 "paper_id": "e2d38543bd3cf813c63df336b21b003156ed48a8",
#                 "corpus_id": 222142136,
#                 "title": "Universal Natural Language Processing with Limited Annotations: Try Few-shot Textual Entailment as a Start"
#             },
#             {
#                 "paper_id": "ebbc2bb679e9cc24cce7b3675c7b93ee9ca7cebf",
#                 "corpus_id": 221556724,
#                 "title": "Central Yup'ik and Machine Translation of Low-Resource Polysynthetic Languages"
#             },
#             {
#                 "paper_id": "ee6200d68ecafc66b32da57d1790937e0ec3d473",
#                 "corpus_id": 226262397,
#                 "title": "Simple Data Augmentation with the Mask Token Improves Domain Adaptation for Dialog Act Tagging"
#             },
#             {
#                 "paper_id": "fc7bf698ece716dc03276d337c1b4b0f755aafca",
#                 "corpus_id": 211068838,
#                 "title": "Limits of Detecting Text Generated by Large-Scale Language Models"
#             },
#             {
#                 "paper_id": "087dd95e13efd47aef2a6582e6801b39fc0f83d8",
#                 "corpus_id": 207847663,
#                 "title": "ERASER: A Benchmark to Evaluate Rationalized NLP Models"
#             },
#             {
#                 "paper_id": "0c5598424cc96d8fb500eb553cb7969f86a0ede0",
#                 "corpus_id": 204976362,
#                 "title": "Evaluating the Factual Consistency of Abstractive Text Summarization"
#             },
#             {
#                 "paper_id": "1dfe26da4a910d7fb745ee9abc678986e8a5dc25",
#                 "corpus_id": 214141639,
#                 "title": "Guided Adaptive Credit Assignment for Sample Efficient Policy Optimization"
#             },
#             {
#                 "paper_id": "1fa4c21ef03887e0a350a575bbbb10a98e195048",
#                 "corpus_id": 204838309,
#                 "title": "Global Capacity Measures for Deep ReLU Networks via Path Sampling"
#             },
#             {
#                 "paper_id": "2224df67ce42be8f7d894e2db3c1b762a10ffd78",
#                 "corpus_id": 232471612,
#                 "title": "Public Dataset for \"Genie"
#             },
#             {
#                 "paper_id": "29e13746fa5aed13e51558a521a39aaeaa99c1b1",
#                 "corpus_id": 57761103,
#                 "title": "Self-Monitoring Navigation Agent via Auxiliary Progress Estimation"
#             },
#             {
#                 "paper_id": "34ca7f54acbb8aaa977115aaf92ad93b04783ba7",
#                 "corpus_id": 149492938,
#                 "title": "MP28-01\u2003ARTIFICIAL INTELLIGENCE (AI) ACCURATELY AUTOMATE AND SPEED IMMUNOFLUORESCENCE (IF)-BASED DISCOVERY AND VALIDATION OF NOVEL PROGNOSTIC AND PREDICTIVE BIOMARKERS IN PROSTATE CANCER"
#             },
#             {
#                 "paper_id": "36bc673153aa08c228db9fe5193b546e8d79cd36",
#                 "corpus_id": 203701451,
#                 "title": "Unifying Question Answering, Text Classification, and Regression via Span Extraction"
#             },
#             {
#                 "paper_id": "3f2514bf6bf1ca25112be036343e3cd5c3c2115b",
#                 "corpus_id": 218469974,
#                 "title": "MKD: a Multi-Task Knowledge Distillation Approach for Pretrained Language Models"
#             },
#             {
#                 "paper_id": "42a7f3e90aa4929d7f01b6124b87f82f7735aa88",
#                 "corpus_id": 90259576,
#                 "title": "Learn to Grow: A Continual Structure Learning Framework for Overcoming Catastrophic Forgetting"
#             },
#             {
#                 "paper_id": "4337eb89a50628c6aa09b95e46c9e456099bcab5",
#                 "corpus_id": 202538698,
#                 "title": "Pretrained AI Models: Performativity, Mobility, and Change"
#             },
#             {
#                 "paper_id": "521b4e26df0f1cf5763dece14cbb218df152dc59",
#                 "corpus_id": 208267807,
#                 "title": "Learning to Retrieve Reasoning Paths over Wikipedia Graph for Question Answering"
#             },
#             {
#                 "paper_id": "545e60873b0fad25407bb6d647f92c905bd2483d",
#                 "corpus_id": 202565697,
#                 "title": "CoSQL: A Conversational Text-to-SQL Challenge Towards Cross-Domain Natural Language Interfaces to Databases"
#             },
#             {
#                 "paper_id": "66605b6ceae9847156526e46ca9fe467804fca54",
#                 "corpus_id": 195767254,
#                 "title": "Learning World Graphs to Accelerate Hierarchical Reinforcement Learning"
#             },
#             {
#                 "paper_id": "6bdbccbe961581d00e5a9c9623ff47e666891b3f",
#                 "corpus_id": 213540268,
#                 "title": "Learning World Graph Decompositions To Accelerate Reinforcement Learning"
#             },
#             {
#                 "paper_id": "75acc731bdd2b626edc74672a30da3bc51010ae8",
#                 "corpus_id": 202573071,
#                 "title": "CTRL: A Conditional Transformer Language Model for Controllable Generation"
#             },
#             {
#                 "paper_id": "78945210cee2356b28393a4f2fdebd219d1c1aeb",
#                 "corpus_id": 204950178,
#                 "title": "Sketch-Fill-A-R: A Persona-Grounded Chit-Chat Generation Framework"
#             },
#             {
#                 "paper_id": "7eb6d0dfdb34227a981a7a6e0eedc2948c7c2bbb",
#                 "corpus_id": 203905404,
#                 "title": "Find or Classify? Dual Strategy for Slot-Value Predictions on Multi-Domain Dialog State Tracking"
#             },
#             {
#                 "paper_id": "81229600243f20a5e224dcb0b4eff190e37594d9",
#                 "corpus_id": 207807013,
#                 "title": "DESC LIMIT 1 LSTM Query Decoder Attention Over Previous Utterances , Column Headers , Previous Query Bi LSTM Query Encoder Table Encoder"
#             },
#             {
#                 "paper_id": "849af2d687d8fee2ffce6281e21b96bac9b86dcb",
#                 "corpus_id": 202118886,
#                 "title": "Part VI Neural Machine Translation , Seq 2 seq and Attention"
#             },
#             {
#                 "paper_id": "874e9318c09c711ecd48a903b3824a3a03e2cd62",
#                 "corpus_id": 174803111,
#                 "title": "Explain Yourself! Leveraging Language Models for Commonsense Reasoning"
#             },
#             {
#                 "paper_id": "8e1a2dfd0ec99a6c37dc8671f5fd78845eff14f7",
#                 "corpus_id": 209202611,
#                 "title": "Learning From Noisy Anchors for One-Stage Object Detection"
#             },
#             {
#                 "paper_id": "9111fb8e3624ae182cf07ffb711beaf6fd4aa070",
#                 "corpus_id": 208139472,
#                 "title": "Predicting with High Correlation Features"
#             },
#             {
#                 "paper_id": "924acc8b76779a5211cc04bbe6cf13bd0bc6e7f8",
#                 "corpus_id": 58006691,
#                 "title": "Global-to-local Memory Pointer Networks for Task-Oriented Dialogue"
#             },
#             {
#                 "paper_id": "963a23a933aabd8f9d896461dd7f25cab39006be",
#                 "corpus_id": 202537466,
#                 "title": "Deleter: Leveraging BERT to Perform Unsupervised Successive Text Compression"
#             },
#             {
#                 "paper_id": "9e10e2cae05b2906330eb7dde2f27042966413b1",
#                 "corpus_id": 125952287,
#                 "title": "Unifying Question Answering and Text Classification via Span Extraction"
#             },
#             {
#                 "paper_id": "9eb4cd1a4b4717c97c47e3dc4563a75779ae9390",
#                 "corpus_id": 207924237,
#                 "title": "BERT is Not an Interlingua and the Bias of Tokenization"
#             },
#             {
#                 "paper_id": "a53e4c66f565b49ae822393f1b26487e100f3ced",
#                 "corpus_id": 212595906,
#                 "title": "Automatic Classification of Cataract based on Deep Learnig"
#             },
#             {
#                 "paper_id": "a758828d2865592fb7ee0c95fe4d2517cf405196",
#                 "corpus_id": 202541654,
#                 "title": "WSLLN:Weakly Supervised Natural Language Localization Networks"
#             },
#             {
#                 "paper_id": "af93e1accba69994cdc36254ef93584af307fd8a",
#                 "corpus_id": 201666437,
#                 "title": "Neural Text Summarization: A Critical Evaluation"
#             },
#             {
#                 "paper_id": "b69ed195aacff0b6410eb3b8431ea968e42620af",
#                 "corpus_id": 207852805,
#                 "title": "Attentive Student Meets Multi-Task Teacher: Improved Knowledge Distillation for Pretrained Models"
#             },
#             {
#                 "paper_id": "bc5c077cc0437e5529aabad7880427fe9a8223ca",
#                 "corpus_id": 202540793,
#                 "title": "Editing-Based SQL Query Generation for Cross-Domain Context-Dependent Questions"
#             },
#             {
#                 "paper_id": "c4285f9d15dc0eedae9174c5ffcd4b7ff42bbcc2",
#                 "corpus_id": 203610450,
#                 "title": "Entropy Penalty: Towards Generalization Beyond the IID Assumption"
#             },
#             {
#                 "paper_id": "c83e78ea1e789f880cb18a8150aee4b135cf45c3",
#                 "corpus_id": 174802420,
#                 "title": "Private Deep Learning with Teacher Ensembles"
#             },
#             {
#                 "paper_id": "c846cbb24866af99a8d02d4c73aa4d7dd1831538",
#                 "corpus_id": 167217746,
#                 "title": "XLDA: Cross-Lingual Data Augmentation for Natural Language Inference and Question Answering"
#             },
#             {
#                 "paper_id": "cd3f6c449d10c9dd6176d6e762ee104904aaccb6",
#                 "corpus_id": 214231302,
#                 "title": "DIME: An Information-Theoretic Difficulty Measure for AI Datasets"
#             },
#             {
#                 "paper_id": "d88bbcf9aa534e6ff78643a0daa68fc75a7e5bdf",
#                 "corpus_id": 174802873,
#                 "title": "SParC: Cross-Domain Semantic Parsing in Context"
#             },
#             {
#                 "paper_id": "db439bcc9088fb9a05c2777cf39a99eeb4e4c5cd",
#                 "corpus_id": 85502269,
#                 "title": "StartNet: Online Detection of Action Start in Untrimmed Videos"
#             },
#             {
#                 "paper_id": "dd4947f1db2d342093fb2ed593ca299b97510e62",
#                 "corpus_id": 174800385,
#                 "title": "Taming MAML: Efficient unbiased meta-reinforcement learning"
#             },
#             {
#                 "paper_id": "e17c13217e1fad11bae46820c4acae1745f69b43",
#                 "corpus_id": 57375723,
#                 "title": "Coarse-grain Fine-grain Coattention Network for Multi-evidence Question Answering"
#             },
#             {
#                 "paper_id": "e30fa08b1ef8f3e7a2394a4467dc0eddcff04681",
#                 "corpus_id": 202767698,
#                 "title": "Keeping Your Distance: Solving Sparse Reward Tasks Using Self-Balancing Shaped Rewards"
#             },
#             {
#                 "paper_id": "ee248883b124a80bdbbc686e906145ccdeadc834",
#                 "corpus_id": 59599587,
#                 "title": "Competitive Experience Replay"
#             },
#             {
#                 "paper_id": "ef5d9069d9b995ccdde479bc3f4f3c389b13d9f2",
#                 "corpus_id": 207892279,
#                 "title": "Near-Zero-Cost Differentially Private Deep Learning with Teacher Ensembles"
#             },
#             {
#                 "paper_id": "f13981668a98173bf6b49310f171a2093167a027",
#                 "corpus_id": 160009896,
#                 "title": "Transferable Multi-Domain State Generator for Task-Oriented Dialogue Systems"
#             },
#             {
#                 "paper_id": "f906264694759f1beda0cb07d02bf098b98c17bb",
#                 "corpus_id": 126147940,
#                 "title": "Genie: a generator of natural language semantic parsers for virtual assistant commands"
#             },
#             {
#                 "paper_id": "fa51365608b4957a3930ed94858114e57815084b",
#                 "corpus_id": 170079088,
#                 "title": "On the Generalization Gap in Reparameterizable Reinforcement Learning"
#             },
#             {
#                 "paper_id": "060400d658b8d271bcc6072416c177ecc8c2f827",
#                 "corpus_id": 219962598,
#                 "title": "Scalable Language Modeling: WikiText-103 on a Single GPU in 12 hours"
#             },
#             {
#                 "paper_id": "087972c66b897e8009f7284ea0b5cd562efcaace",
#                 "corpus_id": 189631852,
#                 "title": "Continual Learning via Explicit Structure Learning"
#             },
#             {
#                 "paper_id": "090294db9fbcfc27e38b11050029bcb6fb794331",
#                 "corpus_id": 29161506,
#                 "title": "Efficient and Robust Question Answering from Minimal Context over Documents"
#             },
#             {
#                 "paper_id": "0a98ef88bae12639d8770e5680564b8f9a188bec",
#                 "corpus_id": 54434554,
# ...
#             },
#             {
#                 "paper_id": "b408198f2c891720738c385272afeeebcd747268",
#                 "corpus_id": 260334522,
#                 "title": "HAGRID: A Human-LLM Collaborative Dataset for Generative Information-Seeking with Attribution"
#             },
#             {
#                 "paper_id": "bda7b805cee90412e7043a333a809d0e78852eb3",
#                 "corpus_id": 259145189,
#                 "title": "Resources for Brewing BEIR: Reproducible Reference Models and an Official Leaderboard"
#             },
#             {
#                 "paper_id": "c198c1193f924953b649002413979e7733c93a48",
#                 "corpus_id": 257232523,
#                 "title": "Spacerini: Plug-and-play Search Engines with Pyserini and Hugging Face"
#             },
#             {
#                 "paper_id": "d68753acfbd0a3d007842884d56a776b45982e6e",
#                 "corpus_id": 256827305,
#                 "title": "Improving Out-of-Distribution Generalization of Neural Rerankers with Contextualized Late Interaction"
#             },
#             {
#                 "paper_id": "e1f513fe13b735b7829c5b7d27040512f189efcb",
#                 "corpus_id": 256827307,
#                 "title": "SLIM: Sparsified Late Interaction for Multi-Vector Retrieval with Inverted Indexes"
#             },
#             {
#                 "paper_id": "e6f9e70182d2b10a9b97541091ecc73c37c6028a",
#                 "corpus_id": 255941578,
#                 "title": "Which Model Shall I Choose? Cost/Quality Trade-offs for Text Classification Tasks"
#             },
#             {
#                 "paper_id": "f170594b13efb4a93ef9819179fc929cac6809bf",
#                 "corpus_id": 260886801,
#                 "title": "Approximating Human-Like Few-shot Learning with GPT-based Compression"
#             },
#             {
#                 "paper_id": "05cb33c55c44ab26848a865eb6062b5b027caacc",
#                 "corpus_id": 250390910,
#                 "title": "An Encoder Attribution Analysis for Dense Passage Retriever in Open-Domain Question Answering"
#             },
#             {
#                 "paper_id": "0c430ea48e37ff43d3ab373ea1441468aa923653",
#                 "corpus_id": 248887666,
#                 "title": "Certified Error Control of Candidate Set Pruning for Two-Stage Relevance Ranking"
#             },
#             {
#                 "paper_id": "34ff09ddf6ae64299564cb673044055b4615fc3c",
#                 "corpus_id": 248987232,
#                 "title": "Domain Adaptation for Memory-Efficient Dense Retrieval"
#             },
#             {
#                 "paper_id": "35a318073ab5b18cf364699e145a750940bcedb3",
#                 "corpus_id": 249319651,
#                 "title": "Neural Query Synthesis and Domain-Specific Ranking Templates for Multi-Stage Clinical Trial Matching"
#             },
#             {
#                 "paper_id": "37d626720f5003373336098ce7c01a1a38e6b63d",
#                 "corpus_id": 252780146,
#                 "title": "What the DAAM: Interpreting Stable Diffusion Using Cross Attention"
#             },
#             {
#                 "paper_id": "38e1a9c5599fc7597b7c5ffd37951ba5f528094c",
#                 "corpus_id": 253107357,
#                 "title": "XRICL: Cross-lingual Retrieval-Augmented In-Context Learning for Cross-lingual Text-to-SQL Semantic Parsing"
#             },
#             {
#                 "paper_id": "3ea4d0bbb313dbaa28e3eb9680879dff80cab84d",
#                 "corpus_id": 247951849,
#                 "title": "Temporal Early Exiting for Streaming Speech Commands Recognition"
#             },
#             {
#                 "paper_id": "423f94251781e9169f2a96bb3208f7feb2a89b0e",
#                 "corpus_id": 250340319,
#                 "title": "Document Expansion Baselines and Learned Sparse Lexical Representations for MS MARCO V1 and V2"
#             },
#             {
#                 "paper_id": "45a3c9be0cc9a9b31e8c524b4a5ab7c43231fc84",
#                 "corpus_id": 252815805,
#                 "title": "Better Than Whitespace: Information Retrieval for Languages without Custom Tokenizers"
#             },
#             {
#                 "paper_id": "5c32c653735b43a0a8923ca65ac191bd4bf15311",
#                 "corpus_id": 254877046,
#                 "title": "Precise Zero-Shot Dense Retrieval without Relevance Labels"
#             },
#             {
#                 "paper_id": "6764157d4e955d712509b842106fb180c9628868",
#                 "corpus_id": 251224409,
#                 "title": "Aggretriever: A Simple Approach to Aggregate Textual Representations for Robust Dense Passage Retrieval"
#             },
#             {
#                 "paper_id": "6e386d1720d9a81386960fcb4daec979ce0731ca",
#                 "corpus_id": 249888962,
#                 "title": "A Dense Representation Framework for Lexical and Semantic Matching"
#             },
#             {
#                 "paper_id": "741a5536c2e58e1595e7396345f1e5d40a3aa775",
#                 "corpus_id": 253708231,
#                 "title": "CITADEL: Conditional Token Interaction via Dynamic Lexical Routing for Efficient and Effective Multi-Vector Retrieval"
#             },
#             {
#                 "paper_id": "754fad16ccde2328b302162571650254acd38203",
#                 "corpus_id": 252872857,
#                 "title": "Query Expansion Using Contextual Clue Sampling with Language Models"
#             },
#             {
#                 "paper_id": "83d373dc961122d207de17bf78b359c04fa489bd",
#                 "corpus_id": 249010242,
#                 "title": "A N E XPLORATION OF V OCABULARY S IZE AND T RANSFER E FFECTS IN M ULTILINGUAL L ANGUAGE M ODELS FOR A FRICAN L ANGUAGES"
#             },
#             {
#                 "paper_id": "8551341fb2ac371ab7de7bc8b32014176a323a1e",
#                 "corpus_id": 254686753,
#                 "title": "Efficient Document-at-a-time and Score-at-a-time Query Evaluation for Learned Sparse Representations"
#             },
#             {
#                 "paper_id": "89beaeacb16e0ee4bbd8fe38a6c3b86de0d3373a",
#                 "corpus_id": 253734385,
#                 "title": "SpeechNet: Weakly Supervised, End-to-End Speech Recognition at Industrial Scale"
#             },
#             {
#                 "paper_id": "8ac975f8ece08246554f1ce9585fb13616a51097",
#                 "corpus_id": 253254958,
#                 "title": "On the Interaction Between Differential Privacy and Gradient Compression in Deep Learning"
#             },
#             {
#                 "paper_id": "8d715cbbec0a66f685e58b6148ad6a5be0d8ead2",
#                 "corpus_id": 248496043,
#                 "title": "To Interpolate or not to Interpolate: PRF, Dense and Sparse Retrievers"
#             },
#             {
#                 "paper_id": "979fd6c0eb8571c170c46903ec2c62a4f7b35bc6",
#                 "corpus_id": 248817938,
#                 "title": "Too Many Relevants: Whither Cranfield Test Collections?"
#             },
#             {
#                 "paper_id": "9d06ef8ecab568b371727df9a47dff3b2e26fc61",
#                 "corpus_id": 254564398,
#                 "title": "Improving Precancerous Case Characterization via Transformer-based Ensemble Learning"
#             },
#             {
#                 "paper_id": "cf387294994faf86b3c8332ba72fc17b1442651c",
#                 "corpus_id": 256461318,
#                 "title": "AfriCLIRMatrix: Enabling Cross-Lingual Information Retrieval for African Languages"
#             },
#             {
#                 "paper_id": "d0629d89120409b6bb2c7cc3b309b15839ff73cb",
#                 "corpus_id": 248003253,
#                 "title": "Squeezing Water from a Stone: A Bag of Tricks for Further Improving Cross-Encoder Effectiveness for Reranking"
#             },
#             {
#                 "paper_id": "d18bf4a546db824f6ed1efcd48b81aa4433b5fec",
#                 "corpus_id": 252901219,
#                 "title": "REBL: Entity Linking at Scale"
#             },
#             {
#                 "paper_id": "d6885ea92c9c720b58f5ed278f5aea42dfdf9918",
#                 "corpus_id": 249953779,
#                 "title": "Few-Shot Non-Parametric Learning with Deep Latent Variable Model"
#             },
#             {
#                 "paper_id": "d821afef2e506c0bbbeb88b4622f2a5a5bb8358b",
#                 "corpus_id": 252968355,
#                 "title": "Making a MIRACL: Multilingual Information Retrieval Across a Continuum of Languages"
#             },
#             {
#                 "paper_id": "e46cd6f065e57adf1321c42890db1a2209e17f7b",
#                 "corpus_id": 252918486,
#                 "title": "VoxelCache: Accelerating Online Mapping in Robotics and 3D Reconstruction Tasks"
#             },
#             {
#                 "paper_id": "eac257efef9ed0230b0036f9c5f478de94333fb6",
#                 "corpus_id": 249319719,
#                 "title": "Document Expansions and Learned Sparse Lexical Representations for MS MARCO V1 and V2"
#             },
#             {
#                 "paper_id": "f0746fd7e2d1c303a46929bdd0bd74b82ede4f2a",
#                 "corpus_id": 259991673,
#                 "title": "Injecting Domain Adaptation with Learning-to-hash for Effective and Efficient Zero-shot Dense Retrieval"
#             },
#             {
#                 "paper_id": "f162b74b73e53e5980e9b3346be370934753acf1",
#                 "corpus_id": 248981599,
#                 "title": "A Common Framework for Exploring Document-at-a-Time and Score-at-a-Time Retrieval Methods"
#             },
#             {
#                 "paper_id": "f9986ca86ef1a617252630c72b3084b039976e5f",
#                 "corpus_id": 251223956,
#                 "title": "Building an Efficiency Pipeline: Commutativity and Cumulativeness of Efficiency Operators for Transformers"
#             },
#             {
#                 "paper_id": "7e8a05e4ce38dffc4e7e3134c6135350133c7183",
#                 "corpus_id": 260478102,
#                 "title": "The Simplest Thing That Can Possibly Work: (Pseudo-)Relevance Feedback via Text Classification"
#             },
#             {
#                 "paper_id": "c3df8f8b7f1ed68f0ffeef6afcf60039f955b397",
#                 "corpus_id": 261242374,
#                 "title": "Overview of the TREC 2021 Deep Learning Track"
#             },
#             {
#                 "paper_id": "3b70f47daef52168f3a6b743ad729cc8b25f5736",
#                 "corpus_id": 254567772,
#                 "title": "The role of index compression in score-at-a-time query evaluation"
#             },
#             {
#                 "paper_id": "a398c7b65cfee1f58ed9383ff66d87b160140056",
#                 "corpus_id": 203572452,
#                 "title": "A High-Performance Architecture for Training"
#             },
#             {
#                 "paper_id": "ccb224b95bc879b7914d0a2c2915f6694fe6160e",
#                 "corpus_id": 254572465,
#                 "title": "Document vector representations for feature extraction in multi-stage document ranking"
#             },
#             {
#                 "paper_id": "b5c1934ee02f70e67b78bb16cdd8fe69c16470ed",
#                 "corpus_id": 257160066,
#                 "title": "From archive to analysis: accessing web archives at scale through a cloud-based interface"
#             },
#             {
#                 "paper_id": "ea2567295df03f9f5983e9f1d4654df60f13cfad",
#                 "corpus_id": 52076607,
#                 "title": "Computing without Servers, V8, Rocket Ships, and Other Batsh*t Crazy Ideas in Data Systems"
#             },
#             {
#                 "paper_id": "e6e5fcf2337da0871708608d63dfca84fe549a6b",
#                 "corpus_id": 44356915,
#                 "title": "Special Issue on Cloud Computing"
#             },
#             {
#                 "paper_id": "01c0f2c0cdc61e2bdba9349ba2e4411f5a5fa29e",
#                 "corpus_id": 35129035,
#                 "title": "Where is the Cloud? Geography, Economics, Environment, and Jurisdiction in Cloud Computing"
#             },
#             {
#                 "paper_id": "0cc26bebbac2d234e8b2e3926bca37215267bc63",
#                 "corpus_id": 7346553,
#                 "title": "Special Issue of the Journal of Parallel and Distributed Computing: Cloud Computing"
#             },
#             {
#                 "paper_id": "42fee5b7c0d96f93172ac64bfef5a888874f3ab6",
#                 "corpus_id": 13114121,
#                 "title": "Searching for SNPs with cloud computing"
#             },
#             {
#                 "paper_id": "72c03c078076a5ed0aaf30715c15736bdf0fcb77",
#                 "corpus_id": 18966271,
#                 "title": "Weathering the Storm: The Policy Implications of Cloud Computing"
#             },
#             {
#                 "paper_id": "e10f432b75868cb3cb97f97f529e12c0d9f4250c",
#                 "corpus_id": 197416485,
#                 "title": "Where is the cloud"
#             },
#             {
#                 "paper_id": "2f82d8ed10d9979020c1c27308ba942f139dd699",
#                 "corpus_id": 60746112,
#                 "title": "Is There a Cloud in your Future? Applications of \"Cloud Computing\" to Web-scale Problems"
#             },
#             {
#                 "paper_id": "93633129b14791f53495c67805655cd32581dce7",
#                 "corpus_id": 144927109,
#                 "title": "Cloud Computing and Information Policy: Computing in a Policy Cloud?"
#             },
#             {
#                 "paper_id": "82e2f68b95a231b8a1261909fe220ef6a12e46ab",
#                 "corpus_id": 262787428,
#                 "title": "Overview of the TREC 2007 Question Answering Track"
#             },
#             {
#                 "paper_id": "532a24fbf508c40234e9126c7a3f80dd92e8545f",
#                 "corpus_id": 257584922,
#                 "title": "Pre-processing Matters! Improved Wikipedia Corpora for Open-Domain Question Answering"
#             },
#             {
#                 "paper_id": "6a0c18aa1bf69798b15ef2355d5256ae8fa80186",
#                 "corpus_id": 257584993,
#                 "title": "PyGaggle: A Gaggle of Resources for Open-Domain Question Answering"
#             },
#             {
#                 "paper_id": "ba03ca8faa9f01cd9d26b80f08d421376f70de22",
#                 "corpus_id": 262825475,
#                 "title": "RankVicuna: Zero-Shot Listwise Document Reranking with Open-Source Large Language Models"
#             },
#             {
#                 "paper_id": "603c11bc7d00c50fd66687a1dda8181e2b593e03",
#                 "corpus_id": 256631010,
#                 "title": "Cross-lingual Text-to-SQL Semantic Parsing with Representation Mixup"
#             },
#             {
#                 "paper_id": "74043ae76b95ad34ee9f31d89549aa1c1c820fed",
#                 "corpus_id": 248003306,
#                 "title": "Another Look at DPR: Reproduction of Training and Replication of Retrieval"
#             },
#             {
#                 "paper_id": "a42bf1ffe610e432b9b7dd627846dec2af110108",
#                 "corpus_id": 216447281,
#                 "title": "Pushback: Characterizing and Detecting Negative Interpersonal Interactions in Code Review"
#             },
#             {
#                 "paper_id": "3c9d137e92ced9bd05c028b39dd33ed3cd6d61fe",
#                 "corpus_id": 205256133,
#                 "title": "Phylogenetic ctDNA analysis depicts early stage lung cancer evolution"
#             },
#             {
#                 "paper_id": "33f50bb38aa2ba5f43528fa53f55c0c81e73a5ad",
#                 "corpus_id": 262787440,
#                 "title": "Overview of the TREC 2006 Question Answering Track | NIST"
#             },
#             {
#                 "paper_id": "72ec50926cc25ae7109bff93a17b9089dcccbc7a",
#                 "corpus_id": 1687044,
#                 "title": "The Roles of Natural Language and XML in the Semantic Web"
#             },
#             {
#                 "paper_id": "7f4ed83a712982774f805230f4c39fe485d5ea55",
#                 "corpus_id": 260482872,
#                 "title": "Answering Definition Questions Using Multiple Knowledge Sources"
#             }
#         ]
#     }
# ]
# Ronak Pradeep
# 27
# 856
# 10
# 27
# Wenhu Chen
# 58
# 2907
# 23
# 58
# R. Socher
# 201
# 124005
# 80
# 201
# Luke Zettlemoyer
# 281
# 66352
# 88
# 281
# Christopher D. Manning
# 526
# 151686
# 136
# 525
# Jimmy Lin
# 572
# 24299
# 76
# 572

# %%
# For the first author in author_details print out all the papers
for paper in author_details[0]["papers"]:
    print(paper["title"])
    print(paper["paper_id"])
    print(paper["corpus_id"])
# Out:
# How Does Generative Retrieval Scale to Millions of Passages?
# 20a7b1e274aff828466bba3760992aa54e14951a
# 258822999
# Pre-processing Matters! Improved Wikipedia Corpora for Open-Domain Question Answering
# 532a24fbf508c40234e9126c7a3f80dd92e8545f
# 257584922
# PyGaggle: A Gaggle of Resources for Open-Domain Question Answering
# 6a0c18aa1bf69798b15ef2355d5256ae8fa80186
# 257584993
# Zero-Shot Listwise Document Reranking with a Large Language Model
# 8be0ec99f80710887e3a8e6bac5fba51a8fd7186
# 258461030
# ReadProbe: A Demo of Retrieval-Enhanced Large Language Models to Support Lateral Reading
# 8dec602dcd4df3db500ad36d01fffd53ec92701a
# 259145284
# Vector Search with OpenAI Embeddings: Lucene Is All You Need
# a08bde10a47059b0ba1e58b425dd080ec9b42339
# 261276669
# RankVicuna: Zero-Shot Listwise Document Reranking with Open-Source Large Language Models
# ba03ca8faa9f01cd9d26b80f08d421376f70de22
# 262825475
# Neural Query Synthesis and Domain-Specific Ranking Templates for Multi-Stage Clinical Trial Matching
# 35a318073ab5b18cf364699e145a750940bcedb3
# 249319651
# Document Expansion Baselines and Learned Sparse Lexical Representations for MS MARCO V1 and V2
# 423f94251781e9169f2a96bb3208f7feb2a89b0e
# 250340319
# Voice Recognition Chat bot for Consumer Product Applications
# 586b9d75afdbb09434c8676fb10a5b0072882bfc
# 252900208
# Another Look at DPR: Reproduction of Training and Replication of Retrieval
# 74043ae76b95ad34ee9f31d89549aa1c1c820fed
# 248003306
# Squeezing Water from a Stone: A Bag of Tricks for Further Improving Cross-Encoder Effectiveness for Reranking
# d0629d89120409b6bb2c7cc3b309b15839ff73cb
# 248003253
# Document Expansions and Learned Sparse Lexical Representations for MS MARCO V1 and V2
# eac257efef9ed0230b0036f9c5f478de94333fb6
# 249319719
# Chatty Goose: A Python Framework for Conversational Search
# 007a06e9674f58d496ef36ef54a2fd1363299c08
# 235351886
# Exploring Listwise Evidence Reasoning with T5 for Fact Verification
# 0c1d53fc87ca482037360b3547111158b505b26e
# 235719102
# Analysing Research Trends Using Topic Modelling and Trend Prediction
# 4e12f790879dcbaa10b43d562f70e926c15b9f50
# 240560203
# Comparison of Foveated Downsampling Techniques in Image Recognition
# 550bdac3647db92f64e5093862209ffc443783f6
# 233268465
# Pyserini: An Easy-to-Use Python Toolkit to Support Replicable IR Research with Sparse and Dense Representations
# 5ac627f229fa8d54f5ad43f7f99e9b29d93ada29
# 231979055
# Vera: Prediction Techniques for Reducing Harmful Misinformation in Consumer Health Search
# 7a4c0523dbb99e2b437ab8e222420e193a517686
# 235477259
# A Replication Study of Dense Passage Retriever
# 89a19523b0cfb587d272b9ceb950c7bc4e8e221e
# 233219855
# Pyserini: A Python Toolkit for Reproducible Information Retrieval Research with Sparse and Dense Representations
# d69c0ed04ecc852e8c921900d3e7967f74f81263
# 235366815
# The Expando-Mono-Duo Design Pattern for Text Ranking with Pretrained Sequence-to-Sequence Models
# e08eed9608382beea1febca49119c665fbabd031
# 231603106
# H2oloo at TREC 2020: When all you got is a hammer... Deep Learning, Health Misinformation, and Precision Medicine
# 4b91247cc0692f34eb3e39485aa3d2d4e8ac9dc5
# 232134157
# Covidex: Neural Ranking Models and Keyword Search Infrastructure for the COVID-19 Open Research Dataset
# e3e36944102c9baee49dfec397fc0e4bb63a7c77
# 220525829
# Scientific Claim Verification with VerT5erini
# e4cb6bfe88a8ed729d34d5a9ff74a992932b70ce
# 225040083
# Document Ranking with a Pretrained Sequence-to-Sequence Model
# f6e0164466e827112fd415afdc28ddf8e0eb1ba3
# 212725651
# Determining a Slogan: The Use of Nominal Group Technique and Q Methology to Develop and Select an Advertising Slogan
# 059fa9a5578cf1ca241b87455eb75803bc6483c0
# 146167879

# %%
from tqdm import tqdm
def get_paper_details(paper_ids, author_id):
    PAPER_DETAIL_FIELDS = "?fields=title,venue,publicationVenue,year,authors,abstract,referenceCount,citationCount,fieldsOfStudy,s2FieldsOfStudy,publicationDate,journal,embedding.specter_v2,tldr"
    papers_info = []
    
    for paper_id in tqdm(paper_ids, desc=f"Fetching papers for author {author_id}", unit="paper"):
        paper_detail_url = f"https://api.semanticscholar.org/graph/v1/paper/{paper_id}" + PAPER_DETAIL_FIELDS
        paper_detail_response = requests.get(paper_detail_url)
        if paper_detail_response.status_code == 200:
            paper_detail = paper_detail_response.json()
            # Convert all None fields to readable format
            for key, value in paper_detail.items():
                if value is None:
                    paper_detail[key] = {}  
            paper_info = {
                "paper_id": paper_detail.get("paperId", ""),
                "corpus_id": paper_detail.get("corpusId", ""),
                "title": paper_detail.get("title", ""),
                "venue": paper_detail.get("venue", ""),
                "publication_venue": paper_detail.get("publicationVenue", ""),
                "year": paper_detail.get("year", ""),
                "authors": [author for author in paper_detail.get("authors", [])],
                "abstract": paper_detail.get("abstract", ""),
                "reference_count": paper_detail.get("referenceCount", ""),
                "citation_count": paper_detail.get("citationCount", ""),
                "fields_of_study": paper_detail.get("fieldsOfStudy", ""),
                "s2_fields_of_study": paper_detail.get("s2FieldsOfStudy", ""),
                "publication_date": paper_detail.get("publicationDate", ""),
                "journal": paper_detail.get("journal", ""),
                "embedding": paper_detail.get("embedding", {}).get("vector", []),
                "tldr": paper_detail.get("tldr", "")
            }
            if 'authors' in paper_info and len(paper_info["authors"]) > 0:
                paper_info["authors"] = [{k: MAP_WRONG_ID_TO_CORRECT_ID.get(v, v) for k, v in author.items()} for author in paper_info["authors"]]                        
            papers_info.append(paper_info)
    return papers_info

# Example usage
for author in author_details:
    print(f"Fetching paper details for author: {author['author_id']} and name {author['author_name']}")
    
    author["paper_details"] = get_paper_details([paper["paper_id"] for paper in author["papers"]], author["author_id"])
    if author["author_id"] in MAP_WRONG_ID_TO_CORRECT_ID:
        author["author_id"] = MAP_WRONG_ID_TO_CORRECT_ID[author["author_id"]]
# Out:
# Fetching paper details for author: 1816753042 and name Ronak Pradeep
# Fetching papers for author 1816753042: 100%|██████████| 27/27 [00:10<00:00,  2.66paper/s]
# Fetching paper details for author: 2928777 and name Wenhu Chen
# Fetching papers for author 2928777: 100%|██████████| 58/58 [00:20<00:00,  2.87paper/s]
# Fetching paper details for author: 2166511 and name R. Socher
# Fetching papers for author 2166511: 100%|██████████| 201/201 [01:13<00:00,  2.75paper/s]
# Fetching paper details for author: 1982950 and name Luke Zettlemoyer
# Fetching papers for author 1982950: 100%|██████████| 281/281 [01:46<00:00,  2.64paper/s]
# Fetching paper details for author: 144783904 and name Christopher D. Manning
# Fetching papers for author 144783904: 100%|██████████| 525/525 [03:05<00:00,  2.83paper/s]
# Fetching paper details for author: 145580839 and name Jimmy Lin
# Fetching papers for author 145580839: 100%|██████████| 572/572 [03:25<00:00,  2.78paper/s]

# %%
# Filter out any paper with paper_id 059fa9a5578cf1ca241b87455eb75803bc6483c0
# Replace tldr with just its text field

# for author in author_details:
#     for paper in author["paper_details"]:
#         if paper["paper_id"] == "059fa9a5578cf1ca241b87455eb75803bc6483c0":
#             author["paper_details"].remove(paper)
#         else:
#             paper["tldr"] = paper["tldr"].get("text", "")

# Filter paper and paper_details that have id "059fa9a5578cf1ca241b87455eb75803bc6483c0":

for author in author_details:
    author["papers"] = [paper for paper in author["papers"] if paper["paper_id"] not in ["586b9d75afdbb09434c8676fb10a5b0072882bfc", "059fa9a5578cf1ca241b87455eb75803bc6483c0"]]
    author["paper_details"] = [paper for paper in author["paper_details"] if paper["paper_id"] not in ["586b9d75afdbb09434c8676fb10a5b0072882bfc", "059fa9a5578cf1ca241b87455eb75803bc6483c0"]]
    print(len(author["papers"]))
# For the first author in author_details print out all the papers
for paper in author_details[0]["papers"]:
    print(paper["title"])
    print(paper["paper_id"])
    print(paper["corpus_id"])
    print(len(author_details[0]["paper_details"]))
    # Print the paper details
    for paper_detail in author_details[0]["paper_details"]:
        if paper_detail["paper_id"] == paper["paper_id"]:
            print(paper_detail["abstract"])
            print(paper_detail["tldr"])
            print(paper_detail["embedding"])
            # Year and date
            print(paper_detail["year"])
            print(paper_detail["publication_date"])
# Out:
# 25
# 58
# 201
# 281
# 525
# 572
# How Does Generative Retrieval Scale to Millions of Passages?
# 20a7b1e274aff828466bba3760992aa54e14951a
# 258822999
# 25
# Popularized by the Differentiable Search Index, the emerging paradigm of generative retrieval re-frames the classic information retrieval problem into a sequence-to-sequence modeling task, forgoing external indices and encoding an entire document corpus within a single Transformer. Although many different approaches have been proposed to improve the effectiveness of generative retrieval, they have only been evaluated on document corpora on the order of 100k in size. We conduct the first empirical study of generative retrieval techniques across various corpus scales, ultimately scaling up to the entire MS MARCO passage ranking task with a corpus of 8.8M passages and evaluating model sizes up to 11B parameters. We uncover several findings about scaling generative retr
 0.4458848536014557, 0.9614619016647339, 0.09772216528654099, 0.12334829568862915, 0.7563461661338806, -0.778892993927002, -0.3777535855770111, -0.8415975570678711, 0.6930401921272278, -0.3958078622817993, 0.4852524697780609, -0.553019642829895, -1.565009593963623, -0.7726967334747314, -0.8942515254020691, 0.22355027496814728, -0.6001148223876953, 0.16443106532096863, 1.181503176689148, 0.35335347056388855, -1.1008975505828857, 0.4268592596054077, -0.2875863015651703, -0.4315986633300781, 0.234355628490448, -0.17554934322834015, 0.505734920501709, -0.7943346500396729, -1.4034533500671387, 0.12767842411994934, -0.011129419319331646, -0.9087951183319092, -0.33261653780937195, -0.5096267461776733, -0.8367218971252441, 0.2721085250377655, 0.07187999039888382, -1.0198830366134644, 0.931209146976471, 0.6717385053634644, -0.6789236664772034, 0.27837997674942017, -0.09125098586082458, 0.10355836153030396, 0.3510698676109314, -0.008969206362962723, -0.33514487743377686, 0.08106335997581482, 0.005774928256869316, 0.1453504115343094, 0.2975430190563202, -0.34100019931793213, 0.04773476719856262, 0.2745451331138611, -0.46841153502464294, 0.2877073884010315, -0.5752770900726318, 0.4534468948841095, -0.7672386169433594, -0.3561418354511261, 0.2507114112377167, 0.49300724267959595, 0.016450004652142525, -0.5245361328125, -0.32471758127212524, -0.7319018244743347, 0.4589165151119232, -0.1814652383 ...
# 2023
# 2023-05-19
# Pre-processing Matters! Improved Wikipedia Corpora for Open-Domain Question Answering
# 532a24fbf508c40234e9126c7a3f80dd92e8545f
# 257584922
# 25
# {}
# {}
# []
# 2023
# {}
# PyGaggle: A Gaggle of Resources for Open-Domain Question Answering
# 6a0c18aa1bf69798b15ef2355d5256ae8fa80186
# 257584993
# 25
# {}
# {}
# []
# 2023
# {}
# Zero-Shot Listwise Document Reranking with a Large Language Model
# 8be0ec99f80710887e3a8e6bac5fba51a8fd7186
# 258461030
# 25
# Supervised ranking methods based on bi-encoder or cross-encoder architectures have shown success in multi-stage text ranking tasks, but they require large amounts of relevance judgments as training data. In this work, we propose Listwise Reranker with a Large Language Model (LRL), which achieves strong reranking effectiveness without using any task-specific training data. Different from the existing pointwise ranking methods, where documents are scored independently and ranked according to the scores, LRL directly generates a reordered list of document identifiers given the candidate documents. Experiments on three TREC web search datasets demonstrate that LRL not only outperforms zero-shot pointwise methods when reranking first-stage retrieval results, but can also act as a final-stage reranker to improve the top-ranked results of a pointwise method for improved efficiency. Additionally, we apply our approach to subsets of MIRACL, a recent multilingual retrieval dataset, with results showing its potential to generalize across different languages.
# {'model': 'tldr@v2.0.0', 'text': 'This work proposes Listwise Reranker with a Large Language Model (LRL), which achieves strong reranking effectiveness without using any task-specific training data, and applies its approach to subsets of MIRACL, a recent multilingual retrieval dataset, with results showing its potential to generalize across different languages.'}
0.0579407662153244, -0.25043657422065735, -1.1273382902145386, 0.17208507657051086, 0.44608956575393677, -0.6169970035552979, 1.0213366746902466, 0.3672991991043091, -1.1900393962860107, 0.24802568554878235, -0.2171371430158615, 0.18024347722530365, 0.35473528504371643, -0.27328401803970337, -0.7170014381408691, -0.05323083698749542, -0.27384090423583984, 0.6662077307701111, 0.08113336563110352, -0.10474080592393875, 0.17324364185333252, 0.40733110904693604, 0.2379455864429474, 0.4420717656612396, -0.8001459836959839, 1.028786301612854, -0.6395670175552368, 0.10348866134881973, 0.21394966542720795, 0.8336332440376282, -0.12118475884199142, 0.0716702938079834, -0.5741584300994873, -1.1276569366455078, -0.04219706729054451, 0.6411802768707275 ...
# 2023
# 2023-08-29
# RankVicuna: Zero-Shot Listwise Document Reranking with Open-Source Large Language Models
# ba03ca8faa9f01cd9d26b80f08d421376f70de22
# 262825475
# 25
# Researchers have successfully applied large language models (LLMs) such as ChatGPT to reranking in an information retrieval context, but to date, such work has mostly been built on proprietary models hidden behind opaque API endpoints. This approach yields experimental results that are not reproducible and non-deterministic, threatening the veracity of outcomes that build on such shaky foundations. To address this significant shortcoming, we present RankVicuna, the first fully open-source LLM capable of performing high-quality listwise reranking in a zero-shot setting. Experimental results on the TREC 2019 and 2020 Deep Learning Tracks show that we can achieve effectiveness comparable to zero-shot reranking with GPT-3.5 with a much smaller 7B parameter model, although our effectiveness remains slightly behind reranking with GPT-4. We hope our work provides the foundation for future research on reranking with modern LLMs. All the code necessary to reproduce our results is available at https://github.com/castorini/rank_llm.
# {'model': 'tldr@v2.0.0', 'text': 'RankVicuna is presented, the first fully open-source LLM capable of performing high-quality listwise reranking in a zero-shot setting and it is hoped this work provides the foundation for future research on reranking with modern LLMs.'}
# [-0.19143639504909515, 0.3649747669696808, -0.4814223349094391, 0.008302553556859493, -0.5917778015136719, -0.35449954867362976, 1.278922200202942, -0.24654565751552582, -0.6947524547576904, -0.016374872997403145, 1.0651836395263672, 0.07778728753328323, -0.09279053658246994, 0.32199686765670776, 0.2704642713069916, 0.0318123884499073, -0.7530603408813477, 1.0957138538360596, 0.02273046039044857, -0.5722550749778748, 0.3186366558074951, -0.9158671498298645, -1.1363831758499146, 0.14919054508209229, 0.4692682921886444, 0.14911329746246338, -0.4285476505756378, 0.7719814777374268, -0.7963168621063232, 0.5921458005905151, 0.4166370630264282, -0.5086060762405396, 0.01809043064713478, 0.1350684016942978, -0.5531503558158875, -0.5210517644882202, 0.7501065731048584, -0.8352023959159851, 0.007722317241132259, 0.8145491480827332, 0.02095874212682247, 0.32605016231536865, 0.4997984766960144, -0.2561345398426056, -0.2380068600177765, 0.8833209872245789, 0.553285539150238, 0.3449709415435791, 0.5341411232948303, -0.8045805096626282, 1.4075285196304321, -1.4659676551818848, 0.5812643766403198, 1.403996229171753, 0.43547046184539795, 0.3527129888534546, -0.07917262613773346, -0.29570719599723816, 0.4765269458293915, 0.004091876093298197, -0.9499216675758362, 0.00342059088870883, -0.40416401624679565, -0.5268972516059875, 1.2032535076141357, -0.
# In this work, we propose an effective multi-stage neural ranking system for the clinical trial matching problem. First, we introduce NQS, a neural query synthesis method that leverages a zero-shot document expansion model to generate multiple sentence-long queries from lengthy patient descriptions. These queries are independently issued to a search engine and the results are fused. We find that on the TREC 2021 Clinical Trials Track, this method outperforms strong traditional baselines like BM25 and BM25 + RM3 by about 12 points in nDCG@10, a relative improvement of 34%. This simple method is so effective that even a state-of-the-art neural relevance ranking method trained on the medical subset of MS MARCO passage, when reranking the results of NQS, fails to improve on the ranked list. Second, we introduce a two-stage neural reranking pipeline trained on clinical trial matching data using tailored ranking templates. In this setting, we can train a pointwise reranker using just 1.1k positive examples and obtain effectiveness improvements over NQS by 24 points. This end-to-end multi-stage system demonstrates a 20% relative effectiveness gain compared to the second-best submission at TREC 2021, making it an important step towards better automated clinical trial matching.
# {'model': 'tldr@v2.0.0', 'text': 'This work introduces NQS, a neural query synthesis method that leverages a zero-shot document expansion model to generate multiple sentence-long queries from lengthy patient descriptions and introduces a two-stage neural reranking pipeline trained on clinical trial matching data using tailored ranking templates.'}
# [0.15166641771793365, 0.16690193116664886, -0.676334798336029, -0.19668754935264587, -0.7144851684570312, -0.07741288095712662, 0.6854966878890991, -0.07082106173038483, -0.6672325730323792, -0.06343594938516617, 0.8119884133338928, -0.10010376572608948, -0.34832969307899475, 0.3214539587497711, 0.32189562916755676, 0.13602828979492188, -0.963253378868103, 0.5383772850036621, -0.10518210381269455, -0.5759108066558838, 0.03302561491727829, -0.5694351196289062, -0.7657805681228638, 0.4526596665382385, 0.41494041681289673, 0.34451183676719666, -0.25968924164772034, 0.666269838809967, -0.09154576063156128, -0.012798918411135674, 0.39189445972442627, -0.26481008529663086, 0.49869057536125183, -0.2685628831386566, -0.35267534852027893, -0.12960734963417053, 0.23839497566223145, -0.5900858044624329, -0.5315540432929993, 0.6848189234733582, 0.643417477607727, 0.5048722624778748, 0.5674805641174316, -0.044233426451683044, -0.5053280591964722, 0.3517506420612335, 0.7270625233650208, 0.48524534702301025, 0.32894039154052734, -0.3962170481681824, 1.0370010137557983, -1.1697466373443604, 0.9086759090423584, 1.221777319908142, 0.28098997473716736, 1.1269949674606323, 0.6133906841278076, -0.13966676592826843, -0.0876854658126831, -0.054282739758491516, -0.6268622279167175, -0.0919446125626564, -0.4306502342224121, -0.28675419092178345, 1.192683458328247, -0.13279315829277039, -0.30339643359184265, 0.25105106830596924, 0.3921395242214203, 0.8441240191459656, -0.2531924247741699, -0.5213682651519775, -0.02906116470694542, -0.07470742613077164, 0.3698314428329468, 0.4429061710834503, -0.5936715006828308, 0.9739683866500854, -0.6851908564567566, -0.49448034167289734, 0.3689292073249817, 0.16255001723766327, -0.020917952060699463, -0.04658692330121994, -0.1568102091550827, 0.4437068998813629, 0.26666271686553955, 0.7426673769950867, -0.23830948770046234, 0.18848560750484467, 0.3202342391014099, 0.2804372012615204, 0.018740274012088776, 0.6579968333244324, 0.17940516769886017, 0.7098442316055298, -0.8368544578552246, 0.5199629664421082, -0.6550013422966003, 0.7202994227409363, -0.616918683052063, -0.24872854351997375, -1.4712549448013306, 0.379332572221756, 1.1288858652114868, -0.39784687757492065, 0.8199955821037292, -0.8050366640090942, -0.2529502511024475, -0.39630457758903503, 0.49541735649108887, -0.33849647641181946, -0.3867602050304413, -0.3461308479309082, -0.7187139987945557, -1.2817209959030151, -0.5873986482620239, 0.29854318499565125, -0.7937529683113098, 0.7830668091773987, -0.30434659123420715, -0.0031069780234247446, 0.227691650390625, 0.9589164853096008, 0.9616769552230835, 0.13615788519382477, 0.3196396231651306, -0.07683327794075012, 1.0638306140899658, -0.5679493546485901, -0.6782540678977966, -0.5513390898704529, 0.8004837036132812, -0.1929604858160019, -0.003351330291479826, -0.39906299114227295, -1.5251295566558838, -0.712274432182312, -0.9653007388114929, 0.1658271998167038, -0.33963632583618164, 0.17754700779914856, 0.8309450149536133, -0.008858575485646725, -0.9438604116439819, 0.9470595121383667, 0.49506574869155884, -0.5816851258277893, -0.0358179472386837, 0.2081463634967804, 0.17013491690158844, -1.0429567098617554, -1.8048428297042847, 0.5122710466384888, -0.07171832770109177, -0.4033679664134979, -0.2166956067085266, -0.5961335301399231, -0.6353098750114441, -0.2173011600971222, 0.4323032796382904, -1.0994869470596313, 1.3335717916488647, 0.37280184030532837, -0.8692205548286438, 0.6696627736091614, -0.052114035934209824, 0.23623953759670258, 0.6511490345001221, 0.36215806007385254, -0.9550417065620422, -0.2094838172197342, 0.09537222236394882, 0.6592368483543396, -0.12271134555339813, 0.44164398312568665, -0.07288294285535812, 0.35550734400749207, -0.2148735523223877, -0.24712426960468292, -0.2220323085784912, 1.0030215978622437, -0.47056320309638977, -0.39757052063941956, 0.20979346334934235, 0.9196922183036804, -0.9068179130554199, -0.20266807079315186, -0.08250410109758377, -1.208902359008789, -0.1090456843376159 ...
# 2022
# 2022-07-06
# Document Expansion Baselines and Learned Sparse Lexical Representations for MS MARCO V1 and V2
# 423f94251781e9169f2a96bb3208f7feb2a89b0e
# 250340319
# 25
# With doc2query, we train a neural sequence-to-sequence model that, given an input span of text, predicts a natural language query that the text might answer. These predictions can be viewed as document expansions that feed standard bag-of-words term weighting models such as BM25 or neural retrieval models based on learned sparse lexical representations such as uniCOIL. Previous experiments on the MS MARCO datasets have demonstrated the effectiveness of these methods, and they serve as baselines that are widely used by the community today. Following the recent release of the MS MARCO V2 passage and document ranking test collections, we have refreshed our doc2query and uniCOIL models. This work describes a number of resources that support competitive, reproducible baselines for both the MS MARCO V1 and V2 test collections using our Anserini and Pyserini IR toolkits. Together, they provide a solid foundation for future research on neural retrieval models using the MS MARCO datasets and beyond.
# {'model': 'tldr@v2.0.0', 'text': 'A number of resources that support competitive, reproducible baselines for both the MS MARCO V1 and V2 test collections using the Anserini and Pyserini IR toolkits are described, providing a solid foundation for future research on neural retrieval models using the MSMARCO datasets and beyond.'}
# [0.0854041650891304, -0.06252717226743698, -0.6895530223846436, 0.10531750321388245, -0.6343743205070496, -0.3112766444683075, 1.0721161365509033, -0.041578128933906555, -0.8699169158935547, 0.04802677780389786, 0.8368238210678101, -0.116743303835392, 0.05990369990468025, 0.19885268807411194, 0.028586892411112785, 0.18938766419887543, -0.7540062665939331, 0.31673842668533325, -0.13063836097717285, -0.8241748809814453, 0.1360711306333542, -0.6716159582138062, -1.1319971084594727, 0.20170198380947113, 0.4275285005569458, 0.5902252793312073, -0.374167263507843, 0.8911765217781067, -0.6943827867507935, 0.03190
0.2288905829191208, -0.3614990711212158, -0.44364356994628906, -0.3717705011367798, -1.3171106576919556, -0.6025250554084778, -0.9792668223381042, -0.02116701565682888, 0.012311608530580997, 0.31256023049354553, 0.785015881061554, 0.0823875293135643, -0.4462360143661499, 1.3006633520126343, 0.3830825984477997, 0.2186524122953415, 0.8064619302749634, -0.12893971800804138, 0.2754182815551758, -0.13322359323501587, -1.4404783248901367, 0.23371648788452148, 0.17663154006004333, -0.5980308651924133, -0.24592018127441406, -0.557255208492279, -0.7729255557060242, -0.20411533117294312, 0.6512285470962524, -0.592719316482544, 1.3125320672988892, 0.2643665075302124, -0.371163010597229, 1.2008411884307861, -0.3501700162887573, -0.17490553855895996, 0.8719960451126099, 0.341701477766037, -0.7396420836448669, 0.1888219714164734, 0.5394652485847473, -0.10140541195869446, 0.5686575770378113, -0.2674201428890228, 0.09275278449058533, 0.3517053425312042, -0.29880720376968384, -0.7969359755516052, 0.275015264749527, 0.8920518159866333, -0.09734152257442474, -0.5471622943878174, 0.11636252701282501, 0.5292893648147583, 0.21383941173553467, 0.09339741617441177, -0.8564664125442505, -1.114348292350769, 0.6206005811691284, -0.3474210798740387, 0.6266 ...
# 2020
# 2020-10-22
# Document Ranking with a Pretrained Sequence-to-Sequence Model
# f6e0164466e827112fd415afdc28ddf8e0eb1ba3
# 212725651
# 25
# This work proposes the use of a pretrained sequence-to-sequence model for document ranking. Our approach is fundamentally different from a commonly adopted classification-based formulation based on encoder-only pretrained transformer architectures such as BERT. We show how a sequence-to-sequence model can be trained to generate relevance labels as “target tokens”, and how the underlying logits of these target tokens can be interpreted as relevance probabilities for ranking. Experimental results on the MS MARCO passage ranking task show that our ranking approach is superior to strong encoder-only models. On three other document retrieval test collections, we demonstrate a zero-shot transfer-based approach that outperforms previous state-of-the-art models requiring in-domain cross-validation. Furthermore, we find that our approach significantly outperforms an encoder-only architecture in a data-poor setting. We investigate this observation in more detail by varying target tokens to probe the model’s use of latent knowledge. Surprisingly, we find that the choice of target tokens impacts effectiveness, even for words that are closely related semantically. This finding sheds some light on why our sequence-to-sequence formulation for document ranking is effective. Code and models are available at pygaggle.ai.
# {'model': 'tldr@v2.0.0', 'text': 'Surprisingly, it is found that the choice of target tokens impacts effectiveness, even for words that are closely related semantically, which sheds some light on why the sequence-to-sequence formulation for document ranking is effective.'}
# [0.2890744209289551, -0.16801542043685913, -0.6622481346130371, -0.2927028238773346, -0.8167926073074341, -0.23545211553573608, 1.0924617052078247, -0.09180649369955063, -0.5443453788757324, 0.022456029430031776, 0.6885254383087158, 0.1749873012304306, -0.3158714771270752, 0.2344995141029358, -0.13757242262363434, 0.06662029772996902, -0.9735558032989502, 0.6644778251647949, 0.08336742967367172, -1.1369094848632812, 0.15071120858192444, -1.1315304040908813, -0.9313668608665466, 0.39805659651756287, 0.35600996017456055, 0.42831122875213623, 0.2153421938419342, 0.7150623202323914, -0.3060874342918396, 0.4198099970817566, 0.24896878004074097, -0.394841730594635, 0.389948308467865, -0.18910165131092072, -0.8728910088539124, -0.44
# 2020
# 2020-03-14

# %%
# Proportion of papers with embeddings in this set

for author in author_details:
    # Print name
    print(author["author_name"])
    # Print proportion of papers with embeddings
    print(len([paper for paper in author["paper_details"] if len(paper["embedding"]) > 0]) / len(author["paper_details"]))
# Out:
# Ronak Pradeep
# 0.92
# Wenhu Chen
# 0.9827586206896551
# R. Socher
# 0.9601990049751243
# Luke Zettlemoyer
# 0.9395017793594306
# Christopher D. Manning
# 0.9314285714285714
# Jimmy Lin
# 0.9370629370629371

# %%
# Save whole thing as JSON
import json
# Make data directory
import os
if not os.path.exists("data"):
    os.makedirs("data")

with open("data/author_details.json", "w") as f:
    json.dump(author_details, f, indent=4)

# %%
import json

# Load author_details.json

with open("data/author_details.json", "r") as f:
    author_details = json.load(f)

# %%
import matplotlib.pyplot as plt
import numpy as np
import json
import pandas as pd
import warnings
import seaborn as sns
import plotly.express as px
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
warnings.filterwarnings('ignore')

BLACKLIST_PAPER_IDS = ['4e12f790879dcbaa10b43d562f70e926c15b9f50', '3c9d137e92ced9bd05c028b39dd33ed3cd6d61fe']
BLACKLIST_PAPER_TITLES = ['Reviewers, Volume 33', 'Facial Emotion Recognition Using PHOG and a Hierarchical Expression Model',
                          'IMPROVING TRADITIONAL BUILDING REPAIR CONSTRUCTION QUALITY USING HISTORIC BUILDING INFORMATION MODELING CONCEPT']
BLACKLIST_AUTHORS = ["D. Cheriton"]
# Filter to only include those papers with an embedding

def to_string_authors(list_of_authors):
    if len(list_of_authors) > 5:
        return ", ".join(list_of_authors[:5]) + ", et al."
    elif len(list_of_authors) > 2:
        return ", ".join(list_of_authors[:-1]) + ", and " + list_of_authors[-1]
    else:
        return " and ".join(list_of_authors)

for author in author_details:
    print(f"Processing {author['author_name']}")
    # Print initial paper length
    print(f"Initial paper length: {len(author['paper_details'])}")

    # Filter papers with embeddings
    papers_with_embeddings = [
        paper for paper in author['paper_details'] if 'embedding' in paper and paper['embedding'] is not None and len(paper['embedding']) > 0 and paper['paper_id'] not in BLACKLIST_PAPER_IDS and paper['title'] not in BLACKLIST_PAPER_TITLES and 'year' in paper and paper['year'] is not None and paper['year'] != {}
    ]
    if not papers_with_embeddings:
        print(f"No papers with embeddings for {author['author_name']}")
        continue
    
    # Print final paper length

    # Extract embeddings and other necessary details
    embeddings = np.array([paper['embedding'] for paper in papers_with_embeddings])
    print("Scaling!")
    scaler = StandardScaler()
    normalized_embeddings = scaler.fit_transform(embeddings)
    clusterer = KMeans(n_clusters=5, n_init=50, max_iter=500, random_state=42)
    clusters = clusterer.fit(normalized_embeddings).labels_

    titles = [paper['title'] for paper in papers_with_embeddings]
    years = [paper['year'] for paper in papers_with_embeddings]

    print("PCA!")
    pca = PCA(n_components=min(50, int(normalized_embeddings.shape[0]/2)), random_state=42)  # Adjust n_components based on the dataset and size of array
    pca_embeddings = pca.fit_transform(normalized_embeddings)

    # Apply t-SNE
    print("t-SNE!")
    tsne = TSNE(n_components=2, n_iter=5000, random_state=42)
    reduced_embeddings = tsne.fit_transform(pca_embeddings)

    # Create a DataFrame for plotly express
    df = pd.DataFrame(reduced_embeddings, columns=['x', 'y'])


    # Ensure all of df is numeric, if not remove
    df = df.apply(pd.to_numeric, errors='coerce')
    # Print count of df
    print(f"Final dataframe length: {len(df)}")
    # Show some examples of df
    df['title'] = titles
    df['year'] = years
    df['cluster'] = clusters
    # Filter paper['authors'] to remove blacklisted authors
    for paper in papers_with_embeddings:
        paper['authors'] = [author for author in paper['authors'] if author['name'] not in BLACKLIST_AUTHORS]
    df['authors'] = [list(map(lambda author: author['name'], paper['authors'])) for paper in papers_with_embeddings]
    # Boolean flag if first author
    df['first_author'] = [author['author_id'] == paper['authors'][0]['authorId'] for paper in papers_with_embeddings]
    # Boolean flag if last author (not first author and very end of the list)
    df['last_author'] = [(len(paper['authors']) != 1) and (author['author_id'] == paper['authors'][-1]['authorId']) for paper in papers_with_embeddings]
    # Boolean flag if middle author
    df['middle_author'] = [not (first_author or last_author) for first_author, last_author in zip(df['first_author'], df['last_author'])]
    # Replace None with empty list
    df['authors'] = df['authors'].apply(lambda authors: authors if authors is not None else [])
    df['authors'] = df['authors'].apply(lambda authors: to_string_authors(authors))
    df['authors'] = df['authors'].apply(lambda authors: authors.replace("Jimmy J.", "Jimmy"))
    # Add author of interest
    df['author_of_interest'] = [author['author_name'].replace("Jimmy J.", "Jimmy") for _ in papers_with_embeddings]
    # Add reference_count and citation_count
    df['reference_count'] = [paper['reference_count'] for paper in papers_with_embeddings]
    df['citation_count'] = [paper['citation_count'] for paper in papers_with_embeddings]
    
    df['tldr'] = [paper['tldr']['text'] if 'tldr' in paper and paper['tldr'] is not None and 'text' in paper['tldr'] else "" for paper in papers_with_embeddings]
    # Replace None with empty string
    df['tldr'] = df['tldr'].apply(lambda tldr: tldr if (tldr is not None and tldr != {}) else '')
    # Venue
    df['venue'] = [paper['venue'] for paper in papers_with_embeddings]
    # Function to add <br> every 10 words
    def add_line_breaks(text):
        words = text.split()
        chunks = [words[i:i+10] for i in range(0, len(words), 10)]
        return '<br>'.join([' '.join(chunk) for chunk in chunks])

    # Apply the function to the 'tldr' column
    df['tldr'] = df['tldr'].apply(add_line_breaks)
    print(df.head())
    # Save df as JSON in data/authors
    if not os.path.exists("data/authors"):
        os.makedirs("data/authors")
    with open(f"data/authors/{author['author_id']}.json", "w") as f:
        json.dump(df.to_dict(), f, indent=4)
# Out:
# Processing Ronak Pradeep
# Initial paper length: 25
# Scaling!
# PCA!
# t-SNE!
# Final dataframe length: 22
#             x           y                                              title  \
# 0   78.973122  -54.079910  How Does Generative Retrieval Scale to Million...
# 1  146.722122  -83.190521  Zero-Shot Listwise Document Reranking with a L...
# 2   -8.229628  139.122910  ReadProbe: A Demo of Retrieval-Enhanced Large ...
# 3  -39.414948 -106.893845  Vector Search with OpenAI Embeddings: Lucene I...
# 4  -96.595345 -154.117599  RankVicuna: Zero-Shot Listwise Document Rerank...
#
#    year  cluster                                            authors  \
# 0  2023        3  Ronak Pradeep, Kai Hui, Jai Gupta, Á. Lelkes, ...
# 1  2023        0  Xueguang Ma, Xinyu Crystina Zhang, Ronak Prade...
# 2  2023        3                       Dake Zhang and Ronak Pradeep
# 3  2023        3  Jimmy Lin, Ronak Pradeep, Tommaso Teofili, and...
# 4  2023        0  Ronak Pradeep, Sahel Sharifymoghaddam, and Jim...
#
#    first_author  last_author  middle_author author_of_interest  \
# 0          True        False          False      Ronak Pradeep
# 1         False        False           True      Ronak Pradeep
# 2         False         True          False      Ronak Pradeep
# 3         False        False           True      Ronak Pradeep
# 4          True        False          False      Ronak Pradeep
#
#    reference_count  citation_count  \
# 0               45               6
# 1               28              11
# 2               21               0
# 3               29               2
# 4               41               2
#
#                                                 tldr      venue
# 0  This work conducts the first empirical study o...  arXiv.org
# 1  This work proposes Listwise Reranker with a La...  arXiv.org
# 2  This paper presents ReadProbe, a tool to suppo...  arXiv.org
# 3  It is shown that hierarchical navigable small-...  arXiv.org
# 4  RankVicuna is presented, the first fully open-...
# Processing Wenhu Chen
# Initial paper length: 58
# Scaling!
# PCA!
# t-SNE!
# Final dataframe length: 55
#           x         y                                              title  \
# 0  4.505535 -2.522324  Few-shot In-context Learning on Knowledge Base...
# 1  2.616723 -4.081278  LyricWhiz: Robust Multilingual Zero-shot Lyric...
# 2  2.771025  0.818058            DreamEdit: Subject-driven Image Editing
# 3  3.982573 -3.476042  Augmenting Black-box LLMs with Medical Textboo...
# 4  2.929568  0.427292  Subject-driven Text-to-Image Generation via Ap...
#
#    year  cluster                                            authors  \
# 0  2023        1  Tianle Li, Xueguang Ma, Alex Zhuang, Yu Gu, Yu...
# 1  2023        4  Le Zhuo, Ruibin Yuan, Jiahao Pan, Yi Ma, Li Yi...
# 2  2023        0        Tianle Li, Max Ku, Cong Wei, and Wenhu Chen
# 3  2023        1             Yubo Wang, Xueguang Ma, and Wenhu Chen
# 4  2023        0  Wenhu Chen, Hexiang Hu, Yandong Li, Nataniel R...
#
#    first_author  last_author  middle_author author_of_interest  \
# 0         False         True          False         Wenhu Chen
# 1         False        False           True         Wenhu Chen
# 2         False         True          False         Wenhu Chen
# 3         False         True          False         Wenhu Chen
# 4          True        False          False         Wenhu Chen
#
#    reference_count  citation_count  \
# 0               59               8
# 1               48               1
# 2               41               4
# 3               39               1
# 4               44              23
#
#                                                 tldr  \
# 0  This work proposes KB-BINDER, which for the fi...
# 1
# 2  This work proposes two novel subject-driven su...
# 3  Despite being 100 times smaller, it is found t...
# 4  Human evaluation shows that SuTI significantly...
#
#                                                venue
# 0  Annual Meeting of the Association for Computat...
# 1                                          arXiv.org
# 2                                          arXiv.org
# 3                                          arXiv.org
# 4                                          arXiv.org
# Processing R. Socher
# Initial paper length: 201
# Scaling!
# PCA!
# t-SNE!
# Final dataframe length: 193
#            x          y                                              title  \
# 0  12.140893   0.902640  Author Correction: Prostate cancer therapy per...
# 1   3.571120 -18.188814  Large language models generate functional prot...
# 2   0.598680  12.946459  The AI Economist: Taxation policy design via t...
# 3   5.615959 -11.220733  Converse: A Tree-Based Modular Task-Oriented D...
# 4  12.075216   0.729035  Prostate cancer therapy personalization via mu...
#
#    year  cluster                                            authors  \
# 0  2023        1  A. Esteva, Jean Feng, D. van der Wal, Shih-Che...
# 1  2023        1  Ali Madani, Ben Krause, E. Greene, Subu Subram...
# 2  2022        1  Stephan Zheng, Alexander R. Trott, Sunil Srini...
# 3  2022        3  Tian Xie, Xinyi Yang, Angela S. Lin, Feihong W...
# 4  2022        1  A. Esteva, Jean Feng, D. van der Wal, Shih-Che...
#
#    first_author  last_author  middle_author author_of_interest  \
# 0         False        False           True          R. Socher
# 1         False        False           True          R. Socher
# 2         False         True          False          R. Socher
# 3         False        False           True          R. Socher
# 4         False        False           True          R. Socher
#
#    reference_count  citation_count  \
# 0                0               0
# 1               98             126
# 2               21              32
# 3               16               7
# 4               43              24
#
#                                                 tldr                 venue
# 0  In the interest of transparency and clinical r...  npj Digital Medicine
# 1  ProGen is described, a language model that can...  Nature Biotechnology
# 2                                                         Science Advances
# 3  Converse is a flexible tree-based modular task...             arXiv.org
# 4  This artificial intelligence-based tool improv...  npj Digital Medicine
# Processing Luke Zettlemoyer
# Initial paper length: 281
# Scaling!
# PCA!
# t-SNE!
# Final dataframe length: 264
#            x         y                                              title  \
# 0  11.011292 -4.306889  REPLUG: Retrieval-Augmented Black-Box Language...
# 1   6.156713  2.418418  ART: Automatic multi-step reasoning and tool-u...
# 2  14.240878 -9.956250  Scaling Autoregressive Multi-Modal Models: Pre...
# 3  18.712572 -5.740767  Stable and low-precision training for large-sc...
# 4  19.185091 -4.790847      QLoRA: Efficient Finetuning of Quantized LLMs
#
#    year  cluster                                            authors  \
# 0  2023        1  Weijia Shi, Sewon Min, Michihiro Yasunaga, Min...
# 1  2023        4  Bhargavi Paranjape, Scott M. Lundberg, Sameer ...
# 2  2023        1  L. Yu, Bowen Shi, Ramakanth Pasunuru, Benjamin...
# 3  2023        1  Mitchell Wortsman, Tim Dettmers, Luke Zettlemo...
# 4  2023        1  Tim Dettmers, Artidoro Pagnoni, Ari Holtzman, ...
#
#    first_author  last_author  middle_author author_of_interest  \
# 0         False        False           True   Luke Zettlemoyer
# 1         False        False           True   Luke Zettlemoyer
# 2         False        False           True   Luke Zettlemoyer
# 3         False        False           True   Luke Zettlemoyer
# 4         False         True          False   Luke Zettlemoyer
#
#    reference_count  citation_count  \
# 0               45              96
# 1               40              39
# 2               41              14
# 3               79               6
# 4               72             160
#
#                                                 tldr      venue
# 0                                                     arXiv.org
# 1  Automatic Reasoning and Tool-use (ART), a fram...  arXiv.org
# 2  CM3Leon is a retrieval-augmented, token-based,...  arXiv.org
# 3  SwitchBack is introduced, a linear layer for i...  arXiv.org
# 4  QLoRA finetuning on a small high-quality datas...  arXiv.org
# Processing Christopher D. Manning
# Initial paper length: 525
# Scaling!
# PCA!
# t-SNE!
# Final dataframe length: 485
#           x          y                                              title  \
# 0  8.143131 -16.985996  Direct Preference Optimization: Your Language ...
# 1  7.262455 -16.721622  Meta-Learning Online Adaptation of Language Mo...
# 2  1.114968 -14.893116                           Backpack Language Models
# 3  5.068863 -13.925661             Holistic Evaluation of Language Models
# 4 -0.926295  -5.084624  Grokking of Hierarchical Structure in Vanilla ...
#
#    year  cluster                                            authors  \
# 0  2023        4  Rafael Rafailov, Archit Sharma, E. Mitchell, S...
# 1  2023        4  Nathan J. Hu, E. Mitchell, Christopher D. Mann...
# 2  2023        4  John Hewitt, John Thickstun, Christopher D. Ma...
# 3  2023        4  Percy Liang, Rishi Bommasani, Tony Lee, Dimitr...
# 4  2023        1  Shikhar Murty, Pratyusha Sharma, Jacob Andreas...
#
#    first_author  last_author  middle_author      author_of_interest  \
# 0         False        False           True  Christopher D. Manning
# 1         False        False           True  Christopher D. Manning
# 2         False        False           True  Christopher D. Manning
# 3         False        False           True  Christopher D. Manning
# 4         False         True          False  Christopher D. Manning
#
#    reference_count  citation_count  \
# 0               44              74
# 1               44               1
# 2               59               5
# 3               68             300
# 4               24               2
#
#                                                 tldr  \
# 0  The experiments show that DPO can fine-tune LM...
# 1  It is hypothesize that online fine-tuning does...
# 2  This work presents Backpacks, a new neural arc...
# 3  HELM is a living benchmark for the community, ...
# 4  This work shows that transformer language mode...
#
#                                                venue
# 0                                          arXiv.org
# 1                                          arXiv.org
# 2  Annual Meeting of the Association for Computat...
# 3         Annals of the New York Academy of Sciences
# 4  Annual Meeting of the Association for Computat...
# Processing Jimmy Lin
# Initial paper length: 572
# Scaling!
# PCA!
# t-SNE!
# Final dataframe length: 531
#            x          y                                              title  \
# 0   1.915803  12.296449  MMEAD: MS MARCO Entity Annotations and Disambi...
# 1  21.707289  10.523269  Evaluating Token-Level and Passage-Level Dense...
# 2  13.042998   2.249099  Towards Best Practices for Training Multilingu...
# 3  21.428070  -5.875742  Another Look at Information Retrieval as Stati...
# 4  20.962545  11.946374  Applying Structural and Dense Semantic Matchin...
#
#    year  cluster                                            authors  \
# 0  2023        1  Chris Kamphuis, Aileen Lin, Siwen Yang, Jimmy ...
# 1  2022        1  Wei Zhong, Jheng-Hong Yang, Yuqing Xie, and Ji...
# 2  2022        1  Xinyu Crystina Zhang, Kelechi Ogueji, Xueguang...
# 3  2022        1             Yuqi Liu, Chengcheng Hu, and Jimmy Lin
# 4  2022        1               Wei Zhong, Yuqing Xie, and Jimmy Lin
#
#    first_author  last_author  middle_author author_of_interest  \
# 0         False        False           True          Jimmy Lin
# 1         False         True          False          Jimmy Lin
# 2         False         True          False          Jimmy Lin
# 3         False         True          False          Jimmy Lin
# 4         False         True          False          Jimmy Lin
#
#    reference_count  citation_count  \
# 0               35               0
# 1               50               8
# 2               70              13
# 3               26               1
# 4               58               4
#
#                                                 tldr  \
# 0  It is shown how to improve recall@1000 and MRR...
# 1  The results show that bi-encoder models are hi...
# 2  This paper focuses on the task of monolingual ...
# 3  It is confirmed that while neural models (part...
# 4  This work describes the participation of the t...
#
#                                                venue
# 0  Annual International ACM SIGIR Conference on R...
# 1  Conference on Empirical Methods in Natural Lan...
# 2            ACM Transactions on Information Systems
# 3  Annual International ACM SIGIR Conference on R...
# 4        Conference and Labs of the Evaluation Forum
